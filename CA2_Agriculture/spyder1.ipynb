# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from bs4 import BeautifulSoup
import requests

# %%
session = requests.Session()

session.headers = {
    "User-Agent":
    "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.110 Safari/537.36",
    "Accept-Encoding": "gzip, deflate",
    "Accept":
    "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/png,*/*;q=0.8",
    "Accept-Language": "en"}

# %%
def get_articles_html(term: str = "cattle", pages=1000):
    query_post_data: dict = {
        'query':
        f'{{"sector":"{term}","error":"","m":"","p":0,"post_parent":"","subpost":"","subpost_id":"","attachment":"","attachment_id":0,"name":"","pagename":"","page_id":0,"second":"","minute":"","hour":"","day":0,"monthnum":0,"year":0,"w":0,"category_name":"","tag":"","cat":"","tag_id":"","author":"","author_name":"","feed":"","tb":"","paged":0,"meta_key":"","meta_value":"","preview":"","s":"","sentence":"","title":"","fields":"","menu_order":"","embed":"","category__in":[],"category__not_in":[],"category__and":[],"post__in":[],"post__not_in":[],"post_name__in":[],"tag__in":[],"tag__not_in":[],"tag__and":[],"tag_slug__in":[],"tag_slug__and":[],"post_parent__in":[],"post_parent__not_in":[],"author__in":[],"author__not_in":[],"ignore_sticky_posts":false,"suppress_filters":false,"cache_results":true,"update_post_term_cache":true,"lazy_load_term_meta":true,"update_post_meta_cache":true,"post_type":"","posts_per_page":130,"nopaging":false,"comments_per_page":"50","no_found_rows":false,"taxonomy":"sector","term":"{term}","order":"DESC"}}',
        'action': 'loadmore',
        'page': '',}
    url: str = "https://www.ifa.ie/wp-admin/admin-ajax.php/"

    page_number: int = 0
    html: str = ""
    receiving_data: bool = True
    while receiving_data and page_number < pages:
        query_post_data['page'] = page_number
        text: str = session.post(url, query_post_data).text
        if not text: receiving_data = False
        else: html += text
        page_number += 1

    print(f"Downloaded {page_number} pages.")
    print(html)
    return html

# %%
def get_articles_links(html: str):
    beautiful_soup = BeautifulSoup(html, 'html.parser')
    links = beautiful_soup.find_all("a", {"class": ""}, href=True)
    print("Article Links found:", len(links))
    return links

# %%
def download_articles_from_links(links, term: str):
    pageList: list = []

    for link in links:
        url: str = link['href']
        response: str = session.get(url)
        beautiful_soup = BeautifulSoup(response.content, 'html.parser')
        heading = beautiful_soup.find('h1').text
        date = beautiful_soup.find('time').text
        html_content = beautiful_soup.find("div", {"class": "single-content"})
        pageList.append([url, heading, date, term, html_content.text, html_content])
    return pageList

# %%
def append_articles_to_csv(pageList, filename):
    
    columns = ["URL", "Heading", "Date", "HTML Content", "Text", "Trend"]
    
    df = pd.DataFrame(pageList, columns=columns)
    df.to_csv(filename, index=False, header=False, mode='a')
    print("Data saved {}".format(filename))

# %%
def create_articles_csv_file(filename: str):
    dataframe_columns = [
        "URL", "Heading", "Date", "Trend", "Text", "HTML Content"]
    dataframe = pd.DataFrame(columns=dataframe_columns)
    dataframe.to_csv(f'{filename}', index=False)
    print(f"Created assets/{filename}")

# %%
def download_articles(term: str, filename: str) -> None:
    html = get_articles_html(term)
    links = get_articles_links(html)
    page_list = download_articles_from_links(links, term)
    append_articles_to_csv(page_list, filename)

# %%
filename = "ifa-ie-articles.csv"
create_articles_csv_file(filename)
terms = ["sheep", "pig","cattle"]
for term in terms:
    download_articles(term, filename)
# Out:
# Created assets/ifa-ie-articles.csv
# Downloaded 42 pages.
#
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/markets-and-prices/beef-sheep-update-6th-may/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2019/04/Cattle1232-370x210.jpg" class="attachment-card size-card wp-post-image" alt="Cattle and Sheep in Wickow Field" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">Beef &#038; Sheep Update 6th May</h4>
#         </a>
#         <a href="https://www.ifa.ie/market-reports/beef-sheep-update/" class="main-term archive-link">Beef &amp; Sheep Update</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/farm-sectors/action-needed-as-sheep-sector-exposed-on-inputs-crisis/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2019/04/Sheep-0987-370x210.jpg" class="attachment-card size-card wp-post-image" alt="Sheep in Wicklow" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">Action Needed as Sheep Sector Exposed on Inputs Crisis</h4>
#         </a>
#         <a href="https://www.ifa.ie/sector/sheep/" class="main-term archive-link">Sheep</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/markets-and-prices/beef-sheep-update-29th-april/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2019/04/Cattle34-370x210.jpg" class="attachment-card size-card wp-post-image" alt="Cattle and Sheep in Wicklow Field, Ireland" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">Beef &#038; Sheep Update 29th April</h4>
#         </a>
#         <a href="https://www.ifa.ie/market-reports/beef-sheep-update/" class="main-term archive-link">Beef &amp; Sheep Update</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/farm-sectors/teagasc-report-highlights-impact-of-inputs-crisis-on-sheep-sector/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2019/04/Sheep-2-370x210.jpg" class="attachment-card size-card wp-post-image" alt="Sheep in Wicklow" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">Teagasc Report Highlights Impact of Inputs Crisis on Sheep Sector</h4>
#         </a>
#         <a href="https://www.ifa.ie/sector/sheep/" class="main-term archive-link">Sheep</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/markets-and-prices/beef-sheep-update/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2019/04/Cattle-Sheep-370x210.jpg" class="attachment-card size-card wp-post-image" alt="Cattle and Sheep in field, Wicklow, Ireland" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">Beef &#038; Sheep Update</h4>
#         </a>
#         <a href="https://www.ifa.ie/market-reports/beef-sheep-update/" class="main-term archive-link">Beef &amp; Sheep Update</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/farm-sectors/price-rises-not-covering-soaring-costs-on-sheep-farms/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2019/04/Sheep-0987-370x210.jpg" class="attachment-card size-card wp-post-image" alt="Sheep in Wicklow" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">Price Rises not Covering Soaring Costs on Sheep Farms</h4>
#         </a>
#         <a href="https://www.ifa.ie/sector/sheep/" class="main-term archive-link">Sheep</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/farm-sectors/sheep-farmers-need-support-to-keep-store-lamb-trade-going/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2019/04/Sheep-9988-370x210.jpg" class="attachment-card size-card wp-post-image" alt="Sheep in Wicklow" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">Sheep Farmers Need Support to Keep Store Lamb Trade Going</h4>
#         </a>
#         <a href="https://www.ifa.ie/sector/sheep/" class="main-term archive-link">Sheep</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/markets-and-prices/beef-sheep-update-25th-march/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2019/04/Cattle-Sheep-370x210.jpg" class="attachment-card size-card wp-post-image" alt="Cattle and Sheep in field, Wicklow, Ireland" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">Beef &#038; Sheep Update 25th March</h4>
#         </a>
#         <a href="https://www.ifa.ie/market-reports/beef-sheep-update/" class="main-term archive-link">Beef &amp; Sheep Update</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/markets-and-prices/beef-sheep-update-11th-march/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2019/04/Cattle1232-370x210.jpg" class="attachment-card size-card wp-post-image" alt="Cattle and Sheep in Wickow Field" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">Beef &#038; Sheep Update 11th March</h4>
#         </a>
#         <a href="https://www.ifa.ie/market-reports/beef-sheep-update/" class="main-term archive-link">Beef &amp; Sheep Update</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/farm-sectors/potential-inputs-shortage-will-have-implications-for-sheep-farmers/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2019/04/Sheep-0987-370x210.jpg" class="attachment-card size-card wp-post-image" alt="Sheep in Wicklow" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">Potential Inputs Shortage Will Have Implications for Sheep Farmers</h4>
#         </a>
#         <a href="https://www.ifa.ie/sector/sheep/" class="main-term archive-link">Sheep</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/markets-and-prices/beef-sheep-update-25th-february/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2019/04/Cattle-Sheep-370x210.jpg" class="attachment-card size-card wp-post-image" alt="Cattle and Sheep in field, Wicklow, Ireland" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">Beef &#038; Sheep Update 25th February</h4>
#         </a>
#         <a href="https://www.ifa.ie/market-reports/beef-sheep-update/" class="main-term archive-link">Beef &amp; Sheep Update</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/farm-sectors/hogget-prices-rise-10c-kg-ifa/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2020/06/Sheep-370x210.jpg" class="attachment-card size-card wp-post-image" alt="" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">Hogget Prices Rise 10c/kg – IFA</h4>
#         </a>
#         <a href="https://www.ifa.ie/sector/sheep/" class="main-term archive-link">Sheep</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/markets-and-prices/beef-sheep-update-18th-february/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2019/04/Cattle-Sheep-370x210.jpg" class="attachment-card size-card wp-post-image" alt="Cattle and Sheep in field, Wicklow, Ireland" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">Beef &#038; Sheep Update 18th February</h4>
#         </a>
#         <a href="https://www.ifa.ie/market-reports/beef-sheep-update/" class="main-term archive-link">Beef &amp; Sheep Update</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/markets-and-prices/beef-sheep-update-11th-february/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2019/04/Cattle34-370x210.jpg" class="attachment-card size-card wp-post-image" alt="Cattle and Sheep in Wicklow Field, Ireland" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">Beef &#038; Sheep Update 11th February</h4>
#         </a>
#         <a href="https://www.ifa.ie/market-reports/beef-sheep-update/" class="main-term archive-link">Beef &amp; Sheep Update</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/farm-sectors/court-case-highlights-deficiencies-in-dog-control-enforcement/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2022/02/No-Dogs-Allowed-campaign-continues-370x210.jpg" class="attachment-card size-card wp-post-image" alt="" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">Court Case Highlights Deficiencies in Dog Control Enforcement</h4>
#         </a>
#         <a href="https://www.ifa.ie/sector/sheep/" class="main-term archive-link">Sheep</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/markets-and-prices/beef-sheep-update-7th-february/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2019/04/Cattle1232-370x210.jpg" class="attachment-card size-card wp-post-image" alt="Cattle and Sheep in Wickow Field" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">Beef &#038; Sheep Update 7th February</h4>
#         </a>
#         <a href="https://www.ifa.ie/market-reports/beef-sheep-update/" class="main-term archive-link">Beef &amp; Sheep Update</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/farm-sectors/tight-supplies-and-strong-demand-push-on-lamb-prices/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2019/04/Sheep-0987-370x210.jpg" class="attachment-card size-card wp-post-image" alt="Sheep in Wicklow" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">Tight Supplies and Strong Demand Push on Lamb Prices</h4>
#         </a>
#         <a href="https://www.ifa.ie/sector/sheep/" class="main-term archive-link">Sheep</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/farm-sectors/minister-commits-at-ifa-agm-to-strengthen-legislation-on-dog-ownership/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2022/01/Minister-at-AGM-370x210.jpeg" class="attachment-card size-card wp-post-image" alt="" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">Minister Commits at IFA AGM to Strengthen Legislation on Dog Ownership</h4>
#         </a>
#         <a href="https://www.ifa.ie/sector/sheep/" class="main-term archive-link">Sheep</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/farm-sectors/increased-food-service-demand-to-drive-lamb-price/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2019/04/Sheep-0987-370x210.jpg" class="attachment-card size-card wp-post-image" alt="Sheep in Wicklow" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">Increased Food Service Demand to Drive Lamb Price</h4>
#         </a>
#         <a href="https://www.ifa.ie/sector/sheep/" class="main-term archive-link">Sheep</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/markets-and-prices/beef-sheep-update-21st-january/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2019/04/Cattle34-370x210.jpg" class="attachment-card size-card wp-post-image" alt="Cattle and Sheep in Wicklow Field, Ireland" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">Beef &#038; Sheep Update 21st January</h4>
#         </a>
#         <a href="https://www.ifa.ie/market-reports/beef-sheep-update/" class="main-term archive-link">Beef &amp; Sheep Update</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/farm-sectors/positive-outlook-for-lamb-prices-ifa/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2019/04/Sheep-0987-370x210.jpg" class="attachment-card size-card wp-post-image" alt="Sheep in Wicklow" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">Positive Outlook for Lamb Prices &#8211; IFA</h4>
#         </a>
#         <a href="https://www.ifa.ie/sector/sheep/" class="main-term archive-link">Sheep</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/markets-and-prices/beef-sheep-update-14th-january/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2019/04/Cattle34-370x210.jpg" class="attachment-card size-card wp-post-image" alt="Cattle and Sheep in Wicklow Field, Ireland" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">Beef &#038; Sheep Update 14th January</h4>
#         </a>
#         <a href="https://www.ifa.ie/market-reports/beef-sheep-update/" class="main-term archive-link">Beef &amp; Sheep Update</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/policy-areas/food-exports-show-the-importance-of-the-sector-to-the-irish-economy/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2020/11/ireland-landscape-370x210.jpg" class="attachment-card size-card wp-post-image" alt="" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">Food Exports Show the Importance of the Sector to the Irish Economy</h4>
#         </a>
#         <a href="https://www.ifa.ie/cross-sectors/economics/" class="main-term archive-link">Economics</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/farm-sectors/lack-of-enforcement-by-authorities-leaves-sheep-flocks-vulnerable-to-attacks/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2022/01/NDA-sign-370x210.jpg" class="attachment-card size-card wp-post-image" alt="" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">Lack of Enforcement by Authorities Leaves Sheep Flocks Vulnerable to Attacks</h4>
#         </a>
#         <a href="https://www.ifa.ie/sector/sheep/" class="main-term archive-link">Sheep</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/markets-and-prices/beef-sheep-update-24th-december/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2019/04/Cattle34-370x210.jpg" class="attachment-card size-card wp-post-image" alt="Cattle and Sheep in Wicklow Field, Ireland" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">Beef &#038; Sheep Update 24th December</h4>
#         </a>
#         <a href="https://www.ifa.ie/market-reports/beef-sheep-update/" class="main-term archive-link">Beef &amp; Sheep Update</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/markets-and-prices/beef-sheep-update-17th-december/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2019/04/Cattle-Sheep-370x210.jpg" class="attachment-card size-card wp-post-image" alt="Cattle and Sheep in field, Wicklow, Ireland" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">Beef &#038; Sheep Update 17th December</h4>
#         </a>
#         <a href="https://www.ifa.ie/market-reports/beef-sheep-update/" class="main-term archive-link">Beef &amp; Sheep Update</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/markets-and-prices/beef-sheep-update-10th-december/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2019/04/Sheep-cattle-99887-370x210.jpg" class="attachment-card size-card wp-post-image" alt="Sheep and Cattle in Wicklow" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">Beef &#038; Sheep Update 10th December</h4>
#         </a>
#         <a href="https://www.ifa.ie/market-reports/beef-sheep-update/" class="main-term archive-link">Beef &amp; Sheep Update</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/farm-sectors/factories-should-provide-eft-facilities-to-farmers/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2019/04/Sheep-8787-370x210.jpg" class="attachment-card size-card wp-post-image" alt="Sheep in Wicklow" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">Factories Should Provide EFT Facilities to Farmers</h4>
#         </a>
#         <a href="https://www.ifa.ie/sector/sheep/" class="main-term archive-link">Sheep</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/markets-and-prices/beef-sheep-update-3rd-december/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2019/04/Cattle-Sheep-370x210.jpg" class="attachment-card size-card wp-post-image" alt="Cattle and Sheep in field, Wicklow, Ireland" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">Beef &#038; Sheep Update 3rd December</h4>
#         </a>
#         <a href="https://www.ifa.ie/market-reports/beef-sheep-update/" class="main-term archive-link">Beef &amp; Sheep Update</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/farm-sectors/new-reference-periods-for-sheep-welfare-scheme-worth-over-e2m-to-sheep-farmers/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2019/04/Sheep-8787-370x210.jpg" class="attachment-card size-card wp-post-image" alt="Sheep in Wicklow" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">New Reference Periods for Sheep Welfare Scheme Worth over €2m to Sheep Farmers</h4>
#         </a>
#         <a href="https://www.ifa.ie/sector/sheep/" class="main-term archive-link">Sheep</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/farm-sectors/attempts-by-factories-to-undermine-lamb-prices-at-odds-with-markets/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2021/02/Sheep-370x210.jpg" class="attachment-card size-card wp-post-image" alt="" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">Attempts by Factories to Undermine Lamb Prices at Odds with Markets</h4>
#         </a>
#         <a href="https://www.ifa.ie/sector/sheep/" class="main-term archive-link">Sheep</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/markets-and-prices/beef-sheep-update-19th-november/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2019/04/Cattle34-370x210.jpg" class="attachment-card size-card wp-post-image" alt="Cattle and Sheep in Wicklow Field, Ireland" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">Beef &#038; Sheep Update 19th November</h4>
#         </a>
#         <a href="https://www.ifa.ie/market-reports/sheep-factory-quotes/" class="main-term archive-link">Sheep Factory Quotes</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/farm-sectors/buoyant-trade-drives-lamb-price-on-40c-kg/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2019/04/Lamb-370x210.jpg" class="attachment-card size-card wp-post-image" alt="" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">Buoyant Trade Drives Lamb Price on 40c/kg</h4>
#         </a>
#         <a href="https://www.ifa.ie/sector/sheep/" class="main-term archive-link">Sheep</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/markets-and-prices/beef-sheep-update-12th-november/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2019/04/Cattle34-370x210.jpg" class="attachment-card size-card wp-post-image" alt="Cattle and Sheep in Wicklow Field, Ireland" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">Beef &#038; Sheep Update 12th November</h4>
#         </a>
#         <a href="https://www.ifa.ie/market-reports/beef-sheep-update/" class="main-term archive-link">Beef &amp; Sheep Update</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/markets-and-prices/beef-sheep-update-6th-november/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2019/04/Cattle-Sheep-370x210.jpg" class="attachment-card size-card wp-post-image" alt="Cattle and Sheep in field, Wicklow, Ireland" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">Beef &#038; Sheep Update 6th November</h4>
#         </a>
#         <a href="https://www.ifa.ie/market-reports/beef-sheep-update/" class="main-term archive-link">Beef &amp; Sheep Update</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/farm-sectors/strong-demand-for-lamb-pushes-price-towards-e7-kg/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2019/04/Sheep-0987-370x210.jpg" class="attachment-card size-card wp-post-image" alt="Sheep in Wicklow" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">Strong Demand for Lamb Pushes Price Towards €7/kg</h4>
#         </a>
#         <a href="https://www.ifa.ie/sector/sheep/" class="main-term archive-link">Sheep</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/farm-sectors/funding-for-sheep-sector-in-new-cap-plan-far-short-of-whats-needed/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2019/04/Sheep1-370x210.jpg" class="attachment-card size-card wp-post-image" alt="" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">Funding for Sheep Sector in New CAP Plan Far Short of What&#8217;s Needed</h4>
#         </a>
#         <a href="https://www.ifa.ie/sector/sheep/" class="main-term archive-link">Sheep</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/markets-and-prices/beef-sheep-update-22nd-october/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2019/04/Sheep-cattle-99887-370x210.jpg" class="attachment-card size-card wp-post-image" alt="Sheep and Cattle in Wicklow" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">Beef &#038; Sheep Update 22nd October</h4>
#         </a>
#         <a href="https://www.ifa.ie/market-reports/beef-sheep-update/" class="main-term archive-link">Beef &amp; Sheep Update</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/farm-sectors/ifa-raise-concerns-over-uk-new-zealand-trade-deal-for-irish-sheep-farmers/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2019/04/Sheep-8787-370x210.jpg" class="attachment-card size-card wp-post-image" alt="Sheep in Wicklow" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">IFA Raise Concerns Over UK-New Zealand Trade Deal for Irish Sheep Farmers</h4>
#         </a>
#         <a href="https://www.ifa.ie/sector/sheep/" class="main-term archive-link">Sheep</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/farm-sectors/further-increases-in-lamb-prices/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2019/04/Sheep-0987-370x210.jpg" class="attachment-card size-card wp-post-image" alt="Sheep in Wicklow" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">Further Increases in Lamb Prices</h4>
#         </a>
#         <a href="https://www.ifa.ie/sector/sheep/" class="main-term archive-link">Sheep</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/markets-and-prices/beef-sheep-update-15th-october/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2019/04/Sheep-cattle-99887-370x210.jpg" class="attachment-card size-card wp-post-image" alt="Sheep and Cattle in Wicklow" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">Beef &#038; Sheep Update 15th October</h4>
#         </a>
#         <a href="https://www.ifa.ie/market-reports/beef-sheep-update/" class="main-term archive-link">Beef &amp; Sheep Update</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/markets-and-prices/beef-sheep-update-9th-october-2/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2019/04/Cattle-sheep-343-e1645723966272-370x210.jpg" class="attachment-card size-card wp-post-image" alt="Suckler Cows Wicklow Cattle" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">Beef &#038; Sheep Update 9th October</h4>
#         </a>
#         <a href="https://www.ifa.ie/market-reports/beef-sheep-update/" class="main-term archive-link">Beef &amp; Sheep Update</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/markets-and-prices/beef-sheep-update-1st-october/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2019/04/Sheep-cattle-99887-370x210.jpg" class="attachment-card size-card wp-post-image" alt="Sheep and Cattle in Wicklow" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">Beef &#038; Sheep Update 1st October</h4>
#         </a>
#         <a href="https://www.ifa.ie/market-reports/beef-sheep-update/" class="main-term archive-link">Beef &amp; Sheep Update</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/markets-and-prices/beef-sheep-update-24th-september/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2019/04/Cattle34-370x210.jpg" class="attachment-card size-card wp-post-image" alt="Cattle and Sheep in Wicklow Field, Ireland" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">Beef &#038; Sheep Update 24th September</h4>
#         </a>
#         <a href="https://www.ifa.ie/market-reports/beef-sheep-update/" class="main-term archive-link">Beef &amp; Sheep Update</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/farm-sectors/scarcity-of-lambs-driving-the-trade-this-week/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2019/04/Sheep-8787-370x210.jpg" class="attachment-card size-card wp-post-image" alt="Sheep in Wicklow" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">Scarcity of Lambs Driving the Trade this Week</h4>
#         </a>
#         <a href="https://www.ifa.ie/sector/sheep/" class="main-term archive-link">Sheep</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/farm-sectors/procedures-around-imports-of-sheep-meat-must-be-strong-and-robust/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2019/04/Sheep-0987-370x210.jpg" class="attachment-card size-card wp-post-image" alt="Sheep in Wicklow" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">Procedures Around Imports of Sheep Meat Must be Strong and Robust</h4>
#         </a>
#         <a href="https://www.ifa.ie/sector/sheep/" class="main-term archive-link">Sheep</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/farm-sectors/new-working-arrangements-could-add-to-dog-attacks/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2021/02/No-Dogs-Allowed-1-370x210.jpg" class="attachment-card size-card wp-post-image" alt="" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">New Working Arrangements Could Add to Dog Attacks</h4>
#         </a>
#         <a href="https://www.ifa.ie/sector/sheep/" class="main-term archive-link">Sheep</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/farm-sectors/funding-of-e30-ewe-key-priority-for-sheep-farmers-in-next-cap/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2019/04/Sheep-0987-370x210.jpg" class="attachment-card size-card wp-post-image" alt="Sheep in Wicklow" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">Funding of €30/ewe Key Priority for Sheep Farmers in next CAP</h4>
#         </a>
#         <a href="https://www.ifa.ie/sector/sheep/" class="main-term archive-link">Sheep</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/markets-and-prices/beef-sheep-update-20th-august/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2019/04/Cattle-sheep-8787-370x210.jpg" class="attachment-card size-card wp-post-image" alt="Cattle and Sheep in Wicklow field" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">Beef &#038; Sheep Update 20th August</h4>
#         </a>
#         <a href="https://www.ifa.ie/market-reports/beef-sheep-update/" class="main-term archive-link">Beef &amp; Sheep Update</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/farm-sectors/lamb-prices-up-on-the-back-of-strong-demand/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2019/04/Sheep-0987-370x210.jpg" class="attachment-card size-card wp-post-image" alt="Sheep in Wicklow" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">Lamb Prices Up on the Back of Strong Demand</h4>
#         </a>
#         <a href="https://www.ifa.ie/sector/sheep/" class="main-term archive-link">Sheep</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/markets-and-prices/beef-sheep-update-13th-august/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2019/04/Cattle34-370x210.jpg" class="attachment-card size-card wp-post-image" alt="Cattle and Sheep in Wicklow Field, Ireland" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">Beef &#038; Sheep Update 13th August</h4>
#         </a>
#         <a href="https://www.ifa.ie/market-reports/beef-sheep-update/" class="main-term archive-link">Beef &amp; Sheep Update</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/markets-and-prices/beef-sheep-update-6th-august/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2019/04/Cattle34-370x210.jpg" class="attachment-card size-card wp-post-image" alt="Cattle and Sheep in Wicklow Field, Ireland" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">Beef &#038; Sheep Update 6th August</h4>
#         </a>
#         <a href="https://www.ifa.ie/market-reports/beef-sheep-update/" class="main-term archive-link">Beef &amp; Sheep Update</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/policy-areas/positive-market-outlook-for-sheep-meat/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2021/02/Sheep-370x210.jpg" class="attachment-card size-card wp-post-image" alt="" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">Positive Market Outlook for Sheep Meat</h4>
#         </a>
#         <a href="https://www.ifa.ie/sector/sheep/" class="main-term archive-link">Sheep</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/markets-and-prices/beef-sheep-update-30th-july/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2019/04/Cattle1232-370x210.jpg" class="attachment-card size-card wp-post-image" alt="Cattle and Sheep in Wickow Field" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">Beef &#038; Sheep Update 30th July</h4>
#         </a>
#         <a href="https://www.ifa.ie/market-reports/beef-sheep-update/" class="main-term archive-link">Beef &amp; Sheep Update</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/markets-and-prices/beef-sheep-update-23rd-july/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2019/04/Cattle-Sheep-370x210.jpg" class="attachment-card size-card wp-post-image" alt="Cattle and Sheep in field, Wicklow, Ireland" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">Beef &#038; Sheep Update 23rd July</h4>
#         </a>
#         <a href="https://www.ifa.ie/market-reports/beef-sheep-update/" class="main-term archive-link">Beef &amp; Sheep Update</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/farm-sectors/demand-ahead-of-the-eid-festival-pushes-lamb-price-on/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2019/04/Lamb-370x210.jpg" class="attachment-card size-card wp-post-image" alt="" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">Demand Ahead of the Eid Festival Pushes Lamb Price On</h4>
#         </a>
#         <a href="https://www.ifa.ie/sector/sheep/" class="main-term archive-link">Sheep</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/markets-and-prices/beef-sheep-update-9th-july/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2019/04/Cattle-Sheep-370x210.jpg" class="attachment-card size-card wp-post-image" alt="Cattle and Sheep in field, Wicklow, Ireland" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">Beef &#038; Sheep Update 9th July</h4>
#         </a>
#         <a href="https://www.ifa.ie/market-reports/beef-sheep-update/" class="main-term archive-link">Beef &amp; Sheep Update</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/farm-sectors/factories-forced-to-move-lamb-prices-up/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2021/02/Sheep-370x210.jpg" class="attachment-card size-card wp-post-image" alt="" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">Factories Forced to Move Lamb Prices Up</h4>
#         </a>
#         <a href="https://www.ifa.ie/sector/sheep/" class="main-term archive-link">Sheep</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/markets-and-prices/beef-sheep-update-2nd-july/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2020/11/rural-sea-2-370x210.jpg" class="attachment-card size-card wp-post-image" alt="" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">Beef &#038; Sheep Update 2nd July</h4>
#         </a>
#         <a href="https://www.ifa.ie/market-reports/beef-sheep-update/" class="main-term archive-link">Beef &amp; Sheep Update</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/farm-sectors/favourable-market-for-lamb-has-to-be-reflected-in-price-to-farmers/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2019/04/Sheep-8787-370x210.jpg" class="attachment-card size-card wp-post-image" alt="Sheep in Wicklow" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">Favourable Market for Lamb has to be Reflected in Price to Farmers</h4>
#         </a>
#         <a href="https://www.ifa.ie/sector/sheep/" class="main-term archive-link">Sheep</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/markets-and-prices/beef-sheep-update-25th-june/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2019/04/Cattle34-370x210.jpg" class="attachment-card size-card wp-post-image" alt="Cattle and Sheep in Wicklow Field, Ireland" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">Beef &#038; Sheep Update 25th June</h4>
#         </a>
#         <a href="https://www.ifa.ie/market-reports/beef-sheep-update/" class="main-term archive-link">Beef &amp; Sheep Update</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/farm-sectors/upcoming-eid-festival-will-help-underpin-lamb-prices/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2019/04/Sheep-0987-370x210.jpg" class="attachment-card size-card wp-post-image" alt="Sheep in Wicklow" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">Upcoming EID Festival Will Help Underpin Lamb Prices</h4>
#         </a>
#         <a href="https://www.ifa.ie/sector/sheep/" class="main-term archive-link">Sheep</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/farm-sectors/farmers-resisting-lower-lamb-quotes-from-factories/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2019/04/Sheep-9988-370x210.jpg" class="attachment-card size-card wp-post-image" alt="Sheep in Wicklow" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">Farmers Resisting Lower Lamb Quotes from Factories</h4>
#         </a>
#         <a href="https://www.ifa.ie/sector/sheep/" class="main-term archive-link">Sheep</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/markets-and-prices/sheep-price-update-21st-june/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2019/04/Sheep-9988-370x210.jpg" class="attachment-card size-card wp-post-image" alt="Sheep in Wicklow" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">Sheep Price Update 21st June</h4>
#         </a>
#         <a href="https://www.ifa.ie/price-updates/sheep-prices/" class="main-term archive-link">Sheep Prices</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/markets-and-prices/beef-sheep-update-18th-june/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2019/04/Cattle1232-370x210.jpg" class="attachment-card size-card wp-post-image" alt="Cattle and Sheep in Wickow Field" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">Beef &#038; Sheep Update 18th June</h4>
#         </a>
#         <a href="https://www.ifa.ie/market-reports/beef-sheep-update/" class="main-term archive-link">Beef &amp; Sheep Update</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/farm-sectors/sanctions-needed-to-deal-with-irresponsible-dog-owners/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2021/06/NDA-gate-370x210.jpg" class="attachment-card size-card wp-post-image" alt="" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">Sanctions Needed to Deal With Irresponsible Dog Owners</h4>
#         </a>
#         <a href="https://www.ifa.ie/sector/cattle/" class="main-term archive-link">Cattle</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/farm-sectors/extremely-tight-supplies-driving-lamb-trade/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2019/04/Sheep-0987-370x210.jpg" class="attachment-card size-card wp-post-image" alt="Sheep in Wicklow" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">Extremely Tight Supplies Driving Lamb Trade</h4>
#         </a>
#         <a href="https://www.ifa.ie/sector/sheep/" class="main-term archive-link">Sheep</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/markets-and-prices/beef-sheep-update-11th-june/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2019/04/Cattle34-370x210.jpg" class="attachment-card size-card wp-post-image" alt="Cattle and Sheep in Wicklow Field, Ireland" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">Beef &#038; Sheep Update 11th June</h4>
#         </a>
#         <a href="https://www.ifa.ie/market-reports/beef-sheep-update/" class="main-term archive-link">Beef &amp; Sheep Update</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/markets-and-prices/beef-sheep-update-4th-june/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2019/04/Cattle34-370x210.jpg" class="attachment-card size-card wp-post-image" alt="Cattle and Sheep in Wicklow Field, Ireland" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">Beef &#038; Sheep Update 4th June</h4>
#         </a>
#         <a href="https://www.ifa.ie/market-reports/beef-sheep-update/" class="main-term archive-link">Beef &amp; Sheep Update</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/markets-and-prices/sheep-price-update-3rd-june/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2021/02/Sheep-370x210.jpg" class="attachment-card size-card wp-post-image" alt="" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">Sheep Price Update 3rd June</h4>
#         </a>
#         <a href="https://www.ifa.ie/price-updates/sheep-prices/" class="main-term archive-link">Sheep Prices</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/farm-sectors/farmers-should-ignore-quotes-as-sheep-market-remains-strong/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2021/02/Sheep-370x210.jpg" class="attachment-card size-card wp-post-image" alt="" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">Farmers Should Ignore Quotes as Sheep Market Remains Strong</h4>
#         </a>
#         <a href="https://www.ifa.ie/sector/sheep/" class="main-term archive-link">Sheep</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/markets-and-prices/beef-sheep-update-14th-may/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2019/04/Cattle-sheep-8787-370x210.jpg" class="attachment-card size-card wp-post-image" alt="Cattle and Sheep in Wicklow field" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">Beef &#038; Sheep Update 14th May</h4>
#         </a>
#         <a href="https://www.ifa.ie/market-reports/beef-sheep-update/" class="main-term archive-link">Beef &amp; Sheep Update</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/markets-and-prices/sheep-price-update-10th-may/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2019/04/Sheep-370x210.jpg" class="attachment-card size-card wp-post-image" alt="Sheep Welfare Scheme" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">Sheep Price Update 10th May</h4>
#         </a>
#         <a href="https://www.ifa.ie/price-updates/sheep-prices/" class="main-term archive-link">Sheep Prices</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/markets-and-prices/beef-sheep-update-7th-may/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2019/04/Sheep-cattle-99887-370x210.jpg" class="attachment-card size-card wp-post-image" alt="Sheep and Cattle in Wicklow" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">Beef &#038; Sheep Update 7th May</h4>
#         </a>
#         <a href="https://www.ifa.ie/market-reports/beef-sheep-update/" class="main-term archive-link">Beef &amp; Sheep Update</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/markets-and-prices/sheep-price-update-6th-may/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2020/11/sheep_lambs_field-370x210.jpg" class="attachment-card size-card wp-post-image" alt="" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">Sheep Price Update 6th May</h4>
#         </a>
#         <a href="https://www.ifa.ie/price-updates/sheep-prices/" class="main-term archive-link">Sheep Prices</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/farm-sectors/full-takeover-of-slaney-and-icm-by-abp-further-erodes-competition/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2020/11/carcase-370x210.jpg" class="attachment-card size-card wp-post-image" alt="" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">Full Takeover of Slaney and ICM by ABP Further Erodes Competition</h4>
#         </a>
#         <a href="https://www.ifa.ie/sector/cattle/" class="main-term archive-link">Cattle</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/farm-sectors/re-opening-of-marts-should-facilitate-sellers-of-livestock/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2019/04/Mart-370x210.jpg" class="attachment-card size-card wp-post-image" alt="" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">Re-Opening of Marts Should Facilitate Sellers of Livestock</h4>
#         </a>
#         <a href="https://www.ifa.ie/sector/cattle/" class="main-term archive-link">Cattle</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/farm-sectors/ifa-meet-icm-and-call-on-authorities-to-validate-imports/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2019/04/Sheep-0987-370x210.jpg" class="attachment-card size-card wp-post-image" alt="Sheep in Wicklow" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">IFA Meet ICM and Call on Authorities to Validate Imports</h4>
#         </a>
#         <a href="https://www.ifa.ie/sector/sheep/" class="main-term archive-link">Sheep</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/farm-sectors/imports-by-icm-undermining-sheep-farmers/">
# ...
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2019/04/sheep-sea-3-370x210.jpg" class="attachment-card size-card wp-post-image" alt="" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">Sheep Farmers Unfairly Scapegoated on Tagging</h4>
#         </a>
#         <a href="https://www.ifa.ie/sector/sheep/" class="main-term archive-link">Sheep</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/farm-sectors/new-bord-bia-promotion-campaign-will-drive-increased-demand-for-lamb/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2019/04/Sheep-9988-370x210.jpg" class="attachment-card size-card wp-post-image" alt="Sheep in Wicklow" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">New Bord Bia Promotion Campaign Will Drive Increased Demand for Lamb</h4>
#         </a>
#         <a href="https://www.ifa.ie/sector/sheep/" class="main-term archive-link">Sheep</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/farm-sectors/strong-market-demand-for-lambs/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2019/04/Sheep-0987-370x210.jpg" class="attachment-card size-card wp-post-image" alt="Sheep in Wicklow" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">Strong Market Demand for Lambs</h4>
#         </a>
#         <a href="https://www.ifa.ie/sector/sheep/" class="main-term archive-link">Sheep</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/farm-sectors/factories-reverse-on-lamb-price-cuts/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2019/04/Sheep-0987-370x210.jpg" class="attachment-card size-card wp-post-image" alt="Sheep in Wicklow" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">Factories Reverse on Lamb Price Cuts</h4>
#         </a>
#         <a href="https://www.ifa.ie/sector/sheep/" class="main-term archive-link">Sheep</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/farm-sectors/lamb-market-to-stabilise-after-vicious-cuts/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2019/04/sheep-rural-898-370x210.jpg" class="attachment-card size-card wp-post-image" alt="" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">Lamb Market to Stabilise After Vicious Cuts</h4>
#         </a>
#         <a href="https://www.ifa.ie/sector/sheep/" class="main-term archive-link">Sheep</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/farm-sectors/farmers-angry-as-factories-undermine-lamb-market/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2019/04/Sheep-2-370x210.jpg" class="attachment-card size-card wp-post-image" alt="Sheep in Wicklow" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">Farmers Angry as Factories Undermine Lamb Market</h4>
#         </a>
#         <a href="https://www.ifa.ie/sector/sheep/" class="main-term archive-link">Sheep</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/farm-sectors/farmers-cannot-carry-cost-of-eid-ifa-makes-submission-to-minister/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2019/04/Sheep-2-370x210.jpg" class="attachment-card size-card wp-post-image" alt="Sheep in Wicklow" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">Farmers Cannot Carry Cost of EID &#8211; IFA Makes Submission to Minister</h4>
#         </a>
#         <a href="https://www.ifa.ie/sector/sheep/" class="main-term archive-link">Sheep</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/farm-sectors/farmer-anger-over-factory-lamb-price-cuts/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2019/04/Sheep-9988-370x210.jpg" class="attachment-card size-card wp-post-image" alt="Sheep in Wicklow" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">Farmer Anger Over Factory Lamb Price Cuts</h4>
#         </a>
#         <a href="https://www.ifa.ie/sector/sheep/" class="main-term archive-link">Sheep</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/campaigns/teagascs-farm-income-survey-highlights-the-importance-of-cap-direct-payments-the-challenges-of-price-volatility-healy/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2019/04/Rural-0000-370x210.jpg" class="attachment-card size-card wp-post-image" alt="" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">Teagasc’s Farm Income Survey Highlights the Importance of CAP Direct Payments &#038; the Challenges of Price Volatility – Healy</h4>
#         </a>
#         <a href="https://www.ifa.ie/ifa-campaigns/farm-incomes/" class="main-term archive-link">Farm Incomes</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/farm-sectors/lamb-trade-buoyant/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2019/04/lambs-370x210.jpg" class="attachment-card size-card wp-post-image" alt="" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">Lamb Trade Buoyant</h4>
#         </a>
#         <a href="https://www.ifa.ie/sector/sheep/" class="main-term archive-link">Sheep</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/farm-sectors/wool-prices-need-to-rise-to-cover-costs/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2019/04/Sheep-8787-370x210.jpg" class="attachment-card size-card wp-post-image" alt="Sheep in Wicklow" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">Wool Prices Need to Rise to Cover Costs</h4>
#         </a>
#         <a href="https://www.ifa.ie/sector/sheep/" class="main-term archive-link">Sheep</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/farm-sectors/ifa-to-make-submission-to-minister-creed-on-electronic-tagging/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2019/04/sheep-sea-3-370x210.jpg" class="attachment-card size-card wp-post-image" alt="" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">IFA to Make Submission to Minister Creed on Electronic Tagging</h4>
#         </a>
#         <a href="https://www.ifa.ie/sector/sheep/" class="main-term archive-link">Sheep</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/farm-sectors/ifa-meets-minister-creed-on-electronic-tagging/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2019/04/Sheep-8787-370x210.jpg" class="attachment-card size-card wp-post-image" alt="Sheep in Wicklow" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">IFA Meets Minister Creed on Electronic Tagging</h4>
#         </a>
#         <a href="https://www.ifa.ie/sector/sheep/" class="main-term archive-link">Sheep</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/markets-and-prices/strong-hogget-and-lamb-trade-for-ramadan-ifa/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2019/04/Sheep-9988-370x210.jpg" class="attachment-card size-card wp-post-image" alt="Sheep in Wicklow" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">Strong Hogget and Lamb Trade for Ramadan &#8211; IFA</h4>
#         </a>
#         <a href="https://www.ifa.ie/market-reports/sheep-factory-quotes/" class="main-term archive-link">Sheep Factory Quotes</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/farm-sectors/minister-creed-ignoring-sheep-farmers-by-imposing-compulsory-electronic-tagging/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2019/04/Sheep-88-370x210.jpg" class="attachment-card size-card wp-post-image" alt="" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">Minister Creed Ignoring Sheep Farmers by Imposing Compulsory Electronic Tagging</h4>
#         </a>
#         <a href="https://www.ifa.ie/sector/sheep/" class="main-term archive-link">Sheep</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/markets-and-prices/sheep-trade-remains-strong/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2019/04/sheep-rural-898-370x210.jpg" class="attachment-card size-card wp-post-image" alt="" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">Sheep Trade Remains Strong</h4>
#         </a>
#         <a href="https://www.ifa.ie/price-updates/sheep-prices/" class="main-term archive-link">Sheep Prices</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/farm-sectors/lamb-trade-remains-strong-in-lead-in-to-ramadan/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2019/04/sheep-rural-898-370x210.jpg" class="attachment-card size-card wp-post-image" alt="" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">Lamb Trade Remains Strong in Lead in to Ramadan</h4>
#         </a>
#         <a href="https://www.ifa.ie/sector/sheep/" class="main-term archive-link">Sheep</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/farm-sectors/ifa-calls-for-payout-of-sheep-welfare-monies-and-meal-voucher-scheme-for-sheep-flocks/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2019/04/sheep-rural-3-370x210.jpg" class="attachment-card size-card wp-post-image" alt="" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">IFA Calls for Payout of Sheep Welfare Monies and Meal Voucher Scheme for Sheep Flocks</h4>
#         </a>
#         <a href="https://www.ifa.ie/sector/sheep/" class="main-term archive-link">Sheep</a>    </div>
# </div>
# <div class="col-6 col-lg-3">
#     <div class="card card-half">
#         <a href="https://www.ifa.ie/farm-sectors/dog-owners-should-be-vigilant-over-easter-weekend/">
#             <img width="370" height="210" src="https://www.ifa.ie/wp-content/uploads/2019/04/Sheep-88-370x210.jpg" class="attachment-card size-card wp-post-image" alt="" loading="lazy" sizes="100vw" />
#             <h4 class="post-title">Dog Owners Should Be Vigilant over Easter Weekend</h4>
#         </a>
#         <a href="https://www.ifa.ie/sector/sheep/" class="main-term archive-link">Sheep</a>    </div>
# </div>
# Article Links found: 328
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [26], in <cell line: 4>()
#       3 terms = ["sheep", "pig","cattle"]
#       4 for term in terms:
# ----> 5     download_articles(term, filename)
#
# Input In [21], in download_articles(term, filename)
#       2 html = get_articles_html(term)
#       3 links = get_articles_links(html)
# ----> 4 page_list = download_articles_from_links(links, term)
#       5 append_articles_to_csv(page_list, filename)
#
# Input In [18], in download_articles_from_links(links, term)
#       5 url: str = link['href']
#       6 response: str = session.get(url)
# ----> 7 beautiful_soup = BeautifulSoup(response.content, 'html.parser')
#       8 heading = beautiful_soup.find('h1').text
#       9 date = beautiful_soup.find('time').text
#
# File C:\ProgramData\Anaconda3\envs\pycarot\lib\site-packages\bs4\__init__.py:333, in BeautifulSoup.__init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     331 self.builder.initialize_soup(self)
#     332 try:
# --> 333     self._feed()
#     334     success = True
#     335     break
#
# File C:\ProgramData\Anaconda3\envs\pycarot\lib\site-packages\bs4\__init__.py:451, in BeautifulSoup._feed(self)
#     448 # Convert the document to Unicode.
#     449 self.builder.reset()
# --> 451 self.builder.feed(self.markup)
#     452 # Close out any unfinished strings and close all the open tags.
#     453 self.endData()
#
# File C:\ProgramData\Anaconda3\envs\pycarot\lib\site-packages\bs4\builder\_htmlparser.py:399, in HTMLParserTreeBuilder.feed(self, markup)
#     397 parser.soup = self.soup
#     398 try:
# --> 399     parser.feed(markup)
#     400     parser.close()
#     401 except HTMLParseError as e:
#
# File C:\ProgramData\Anaconda3\envs\pycarot\lib\html\parser.py:111, in HTMLParser.feed(self, data)
#     105 r"""Feed data to the parser.
#     106
#     107 Call this as often as you want, with as little or as much text
#     108 as you want (may include '\n').
#     109 """
#     110 self.rawdata = self.rawdata + data
# --> 111 self.goahead(0)
#
# File C:\ProgramData\Anaconda3\envs\pycarot\lib\html\parser.py:171, in HTMLParser.goahead(self, end)
#     169 if startswith('<', i):
#     170     if starttagopen.match(rawdata, i): # < + letter
# --> 171         k = self.parse_starttag(i)
#     172     elif startswith("</", i):
#     173         k = self.parse_endtag(i)
#
# File C:\ProgramData\Anaconda3\envs\pycarot\lib\html\parser.py:345, in HTMLParser.parse_starttag(self, i)
#     343     self.handle_startendtag(tag, attrs)
#     344 else:
# --> 345     self.handle_starttag(tag, attrs)
#     346     if tag in self.CDATA_CONTENT_ELEMENTS:
#     347         self.set_cdata_mode(tag)
#
# File C:\ProgramData\Anaconda3\envs\pycarot\lib\site-packages\bs4\builder\_htmlparser.py:154, in BeautifulSoupHTMLParser.handle_starttag(self, name, attrs, handle_empty_element)
#     152 #print("START", name)
#     153 sourceline, sourcepos = self.getpos()
# --> 154 tag = self.soup.handle_starttag(
#     155     name, None, None, attr_dict, sourceline=sourceline,
#     156     sourcepos=sourcepos
#     157 )
#     158 if tag and tag.is_empty_element and handle_empty_element:
#     159     # Unlike other parsers, html.parser doesn't send separate end tag
#     160     # events for empty-element tags. (It's handled in
#    (...)
#     166     # don't want handle_endtag() to cross off any previous end
#     167     # events for tags of this name.
#     168     self.handle_endtag(name, check_already_closed=False)
#
# File C:\ProgramData\Anaconda3\envs\pycarot\lib\site-packages\bs4\__init__.py:714, in BeautifulSoup.handle_starttag(self, name, namespace, nsprefix, attrs, sourceline, sourcepos, namespaces)
#     696 """Called by the tree builder when a new tag is encountered.
#     697
#     698 :param name: Name of the tag.
#    (...)
#     711 don't call handle_endtag.
#     712 """
#     713 # print("Start tag %s: %s" % (name, attrs))
# --> 714 self.endData()
#     716 if (self.parse_only and len(self.tagStack) <= 1
#     717     and (self.parse_only.text
#     718          or not self.parse_only.search_tag(name, attrs))):
#     719     return None
#
# File C:\ProgramData\Anaconda3\envs\pycarot\lib\site-packages\bs4\__init__.py:589, in BeautifulSoup.endData(self, containerClass)
#     586     return
#     588 containerClass = self.string_container(containerClass)
# --> 589 o = containerClass(current_data)
#     590 self.object_was_parsed(o)
#
# File C:\ProgramData\Anaconda3\envs\pycarot\lib\site-packages\bs4\element.py:946, in NavigableString.__new__(cls, value)
#     944 else:
#     945     u = str.__new__(cls, value, DEFAULT_OUTPUT_ENCODING)
# --> 946 u.setup()
#     947 return u
#
# KeyboardInterrupt:

# %%
https://www.farmersjournal.ie/#

# %%
from requests.auth import AuthBase
from requests.auth import HTTPBasicAuth

# %%
url = 'https://www.farmersjournal.ie/myjournal/newsfeed'

# %%
auth = HTTPBasicAuth('sba19035@student.cct.ie', 'lucan123')
r = requests.post('https://www.farmersjournal.ie/', auth=auth)
r = requests.get(url)
print(r.text)
# Out:
#     <script>
#         localStorage.setItem('go_to_epaper_after_login', 'https://www.farmersjournal.ie/myjournal/newsfeed');
#         window.location.replace("https://www.farmersjournal.ie/login.php");
#     </script>
#
#
#
#
#
#
# <!-- maybe header location, do not process anything before header -->
# <!-- on this screen don't need load sitecookiechecker.php because the verification needs to be diferent, and happening above -->
#
#     <!DOCTYPE html>
#     <html lang="en" dir="ltr" class="sid-plesk">
#
#     <head><!-- CookiePro Cookies Consent Notice start for farmersjournal.ie -->
# <!--<script type="text/javascript" src="https://cookie-cdn.cookiepro.com/consent/8dfdee53-14a0-4330-a2cf-704812646490/OtAutoBlock.js" ></script>
# <script src="https://cookie-cdn.cookiepro.com/scripttemplates/otSDKStub.js"  type="text/javascript" charset="UTF-8" data-domain-script="8dfdee53-14a0-4330-a2cf-704812646490" ></script>
# <script type="text/javascript">
# function OptanonWrapper() { }
# </script>-->
# <!-- CookiePro Cookies Consent Notice end for farmersjournal.ie -->
#
#
# <!-- Start of HubSpot Embed Code -->
# <!--<script type="text/javascript" id="hs-script-loader" async defer src="//js-eu1.hs-scripts.com/24904274.js"></script>-->
# <!-- End of HubSpot Embed Code -->
#
#
# <!-- secureprivacy.php -->
#
# <!--<script type="text/javascript" src="js/secure-privacy/5fa123407df5d242b85fbe11.js"></script>-->
#
#
# <!--<script type="text/javascript" src="https://app.secureprivacy.ai/script/5fa123407df5d242b85fbe11.js"></script>-->
#
#
#  <!--<meta http-equiv="Content-Security-Policy" content="worker-src * data: 'unsafe-eval' 'unsafe-inline' blob:  default-src self * players.brightcove.net 'unsafe-inline' 'unsafe-eval' * safeframe.googlesyndication.com * https://securepubads.g.doubleclick.net * https://securepubads.g.doubleclick.net  * https://widget.spreaker.com * https://www.google.com * https://tpc.googlesyndication.com * https://pagead2.googlesyndication.com * stats.g.doubleclick.net 'unsafe-inline' 'unsafe-eval' * googleads.g.doubleclick.net 'unsafe-inline' 'unsafe-eval' * googleads.g.doubleclick.net 'unsafe-inline' 'unsafe-eval' * www.google-analytics.com 'unsafe-inline' 'unsafe-eval' * player.vimeo.com 'unsafe-inline' 'unsafe-eval' * www.spreaker.com 'unsafe-inline' 'unsafe-eval' * api-prod.secureprivacy.ai 'unsafe-inline' 'unsafe-eval' * fonts.gstatic.com 'unsafe-inline' 'unsafe-eval' * farmersjournal.ie 'unsafe-inline' 'unsafe-eval' * api.spreaker.com 'unsafe-inline' 'unsafe-eval' ; img-src 'self' data: 'unsafe-inline' 'unsafe-eval' * tpc.googlesyndication.com * https://pagead2.googlesyndication.com * https://www.google.com * https://www.google.ie  * www.google-analytics.com 'unsafe-inline' 'unsafe-eval' * facebook.com 'unsafe-inline' 'unsafe-eval' * app.secureprivacy.ai  * i.vimeocdn.com 'unsafe-inline' 'unsafe-eval' * t.co 'unsafe-inline' 'unsafe-eval' * d3mdtxxgfz6upn.cloudfront.net 'unsafe-inline' 'unsafe-eval'  * s3-eu-west-1.amazonaws.com 'unsafe-inline' 'unsafe-eval'; style-src 'self' * players.brightcove.net 'unsafe-inline' 'unsafe-eval' * www.google.com 'unsafe-inline' 'unsafe-eval' * app.secureprivacy.ai 'unsafe-inline' 'unsafe-eval' * fonts.googleapis.com 'unsafe-inline' 'unsafe-eval'; script-src 'self' * https://www.farmersjournal.ie 'unsafe-inline' 'unsafe-eval' * players.brightcove.net 'unsafe-inline' 'unsafe-eval' * cdn.jsdelivr.net * https://tpc.googlesyndication.com * api.swiftype.com partner.googleadservices.com * adservice.google.com * twitter.github.io * ajax.googleapis.com * adservice.google.ie 'unsafe-inline' 'unsafe-eval' * googleads.g.doubleclick.net 'unsafe-inline' 'unsafe-eval' * googleads.g.doubleclick.net 'unsafe-inline' 'unsafe-eval' * www.googletagservices.com 'unsafe-inline' 'unsafe-eval'  * connect.facebook.net 'unsafe-inline' 'unsafe-eval' * www.google-analytics.com 'unsafe-inline' 'unsafe-eval' * www.googleadservices.com 'unsafe-inline' 'unsafe-eval' * pagead2.googlesyndication.com 'unsafe-inline' 'unsafe-eval'  * www.google.com 'unsafe-inline' 'unsafe-eval' * app.secureprivacy.ai 'unsafe-inline' 'unsafe-eval' * api.farmersjournal.ie 'unsafe-inline' 'unsafe-eval' * fonts.googleapis.com 'unsafe-inline' 'unsafe-eval' * www.googletagmanager.com 'unsafe-inline' 'unsafe-eval' * static.ads-twitter.com 'unsafe-inline' 'unsafe-eval' * analytics.twitter.com 'unsafe-inline' 'unsafe-eval' * securepubads.g.doubleclick.net 'unsafe-inline' 'unsafe-eval' * platform.twitter.com 'unsafe-inline' 'unsafe-eval' * cse.google.com 'unsafe-inline' 'unsafe-eval'">-->
#
# <!-- secureprivacy.php -->        <title>Irish Farmers Journal</title>
#         <meta charset="utf-8">
#         <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">
#         <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0">
#         <meta http-equiv="Cache-Control" content="no-cache">
#         <link rel="canonical" href="https://www.farmersjournal.ie/myjournal" />
#
#         <!-- type="text/plain" data-cookie-if="analytical" -->
# <script data-ad-client="ca-pub-8514379819566682" async src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js" integrity="sha512-2OGxnxdeju0xN0hZPcC2/CCkHBCrCdKxQK3Dtf2Ujc7FWQF0f5DYd6trUJyd++g/37b+9BRf5A9ZU2tHiknijA==" crossorigin="anonymous"></script>
#
#
# <!-- Google Tag Manager -->
# <!-- type="text/plain" data-cookie-if="analytical" -->
# <!--<script  type="text/plain" class="optanon-category-C0002">(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-W2FCP4H');</script>-->
# <!-- End Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-W2FCP4H');</script>
# <!-- End Google Tag Manager -->
#
#
#
#
#
#
# <style>@import https://fonts.googleapis.com/css?family=Roboto:400,100,100italic,300,300italic,400italic,500,500italic,700,700italic,900,900italic;html{font-family:sans-serif;-webkit-text-size-adjust:100%;-ms-text-size-adjust:100%}body{margin:0}footer,header,nav,section{display:block}[hidden]{display:none}a{background-color:transparent}h1{margin:.67em 0;font-size:2em}img{border:0}button,input,select{margin:0;font:inherit;color:inherit}button{overflow:visible}button,select{text-transform:none}button{margin:0;font:inherit;color:inherit;overflow:visible;text-transform:none;-webkit-appearance:button}button::-moz-focus-inner,input::-moz-focus-inner{padding:0;border:0}input{line-height:normal}input[type="checkbox"],input[type="radio"]{-webkit-box-sizing:border-box;-moz-box-sizing:border-box;box-sizing:border-box;padding:0}hr{height:0;-webkit-box-sizing:content-box;-moz-box-sizing:content-box;box-sizing:content-box}@font-face{font-family:'Glyphicons Halflings';src:url(../fonts/glyphicons-halflings-regular.eot);src:url(../fonts/glyphicons-halflings-regular.eot?#iefix) format("embedded-opentype"),url(../fonts/glyphicons-halflings-regular.woff2) format("woff2"),url(../fonts/glyphicons-halflings-regular.woff) format("woff"),url(../fonts/glyphicons-halflings-regular.ttf) format("truetype"),url(../fonts/glyphicons-halflings-regular.svg#glyphicons_halflingsregular) format("svg")}.glyphicon{position:relative;top:1px;display:inline-block;font-family:'Glyphicons Halflings';font-style:normal;font-weight:400;line-height:1;-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale}.glyphicon-envelope:before{content:"\2709"}.glyphicon-ok:before{content:"\e013"}.glyphicon-shopping-cart:before{content:"\e116"}*{-webkit-box-sizing:border-box;-moz-box-sizing:border-box;box-sizing:border-box}:before,:after{-webkit-box-sizing:border-box;-moz-box-sizing:border-box;box-sizing:border-box}html{font-size:10px}body{font-family:"Helvetica Neue",Helvetica,Arial,sans-serif;font-size:14px;line-height:1.42857143;color:#333;background-color:#fff}input,button,select{font-family:inherit;font-size:inherit;line-height:inherit}a{color:#337ab7;text-decoration:none}img{vertical-align:middle}.sr-only{position:absolute;width:1px;height:1px;padding:0;margin:-1px;overflow:hidden;clip:rect(0,0,0,0);border:0}h1,h3,h4{font-family:inherit;font-weight:500;line-height:1.1;color:inherit}hr{margin-top:20px;margin-bottom:20px;border:0;border-top:1px solid #eee}h1,.h1{font-family:inherit;font-weight:500;line-height:1.1;color:inherit;margin-top:20px;margin-bottom:10px;font-size:36px}h1,h3{margin-top:20px;margin-bottom:10px}h4{margin-top:10px;margin-bottom:10px}h1{font-size:36px}h3{font-size:24px}h4{font-size:18px}p{margin:0 0 10px}.text-left{text-align:left}ul{margin-top:0;margin-bottom:10px}ul ul{margin-bottom:0}.container{padding-right:15px;padding-left:15px;margin-right:auto;margin-left:auto}@media (min-width:768px){.container{width:750px}}@media (min-width:992px){.container{width:970px}}@media (min-width:1200px){.container{width:1170px}}.container-fluid{padding-right:15px;padding-left:15px;margin-right:auto;margin-left:auto}.row{margin-right:-15px;margin-left:-15px}.col-md-2,.col-md-3,.col-md-4,.col-md-5,.col-md-7,.col-md-6,.col-md-8,.col-md-9,.col-md-12,.col-sm-2,.col-sm-3,.col-sm-4,.col-sm-6,.col-sm-8,.col-sm-9,.col-sm-10,.col-lg-4{position:relative;min-height:1px;padding-right:15px;padding-left:15px}@media (min-width:768px){.col-sm-2,.col-sm-3,.col-sm-4,.col-sm-6,.col-sm-8,.col-sm-9,.col-sm-10{float:left}.col-sm-10{width:83.33333333%}.col-sm-9{width:75%}.col-sm-8{width:66.66666667%}.col-sm-6{width:50%}.col-sm-4{width:33.33333333%}.col-sm-3{width:25%}.col-sm-2{width:16.66666667%}}@media (min-width:992px){.col-md-2,.col-md-3,.col-md-4,.col-md-5,.col-md-6,.col-md-7,.col-md-8,.col-md-9,.col-md-12{float:left}.col-md-12{width:100%}.col-md-9{width:75%}.col-md-8{width:66.66666667%}.col-md-7{width:58.33333333%}.col-md-6{width:50%}.col-md-4{width:33.33333333%}.col-md-5{width:41.66 ...
# <!-- the most of pages -->
#
#
#
#
#
#
#
#
#
#
# <script type="text/javascript" src="/js/jquery-3.2.1.min.js"></script>
# <script type="text/javascript" src="/js/jquery-migrate-3.js"></script>
#
#
#
# <!--  type="text/plain" data-cookie-if="analytical" -->
# <script>
#   window.fbAsyncInit = function() {
#     FB.init({
#       appId            : '1959631247585700',
#       autoLogAppEvents : true,
#       xfbml            : true,
#       version          : 'v2.11'
#     });
#   };
#
#   (function(d, s, id){
#      var js, fjs = d.getElementsByTagName(s)[0];
#      if (d.getElementById(id)) {return;}
#      js = d.createElement(s); js.id = id;
#      js.src = "https://connect.facebook.net/en_US/sdk.js";
#      fjs.parentNode.insertBefore(js, fjs);
#    }(document, 'script', 'facebook-jssdk'));
# </script>
#
#
#
# <!-- Facebook Pixel Code -->
# <!--type="text/plain" data-cookie-if="analytical"-->
# <script>
# !function(f,b,e,v,n,t,s)
# {if(f.fbq)return;n=f.fbq=function(){n.callMethod?
# n.callMethod.apply(n,arguments):n.queue.push(arguments)};
# if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';
# n.queue=[];t=b.createElement(e);t.async=!0;
# t.src=v;s=b.getElementsByTagName(e)[0];
# s.parentNode.insertBefore(t,s)}(window,document,'script',
# 'https://connect.facebook.net/en_US/fbevents.js');
#  fbq('init', '410644685958601');
# fbq('track', 'PageView');
# </script>
# <noscript>
#  <img height="1" width="1" src="https://www.facebook.com/tr?id=410644685958601&ev=PageView&noscript=1"/>
# </noscript>
# <!-- End Facebook Pixel Code -->
#
# <!-- Twitter single-event website tag code -->
# <!--<script type="text/plain" class="optanon-category-C0002" src="js/static.ads-twitter.com/oct.js" type="text/javascript"></script>-->
# <script src="js/static.ads-twitter.com/oct.js" type="text/javascript"></script>
#
# <!-- static.ads-twitter.com/oct.js -->
#
# <!--  type="text/plain" data-cookie-if="analytical" -->
# <script type="text/javascript">twttr.conversion.trackPid('nuhyy', { tw_sale_amount: 0, tw_order_quantity: 0 });</script>
# <noscript>
# <img height="1" width="1" style="display:none;" alt="" src="https://analytics.twitter.com/i/adsct?txn_id=nuhyy&p_id=Twitter&tw_sale_amount=0&tw_order_quantity=0" />
# <img height="1" width="1" style="display:none;" alt="" src="//t.co/i/adsct?txn_id=nuhyy&p_id=Twitter&tw_sale_amount=0&tw_order_quantity=0" />
# </noscript>
# <!-- End Twitter single-event website tag code -->
#
#
#
#
#
#
#
# <script type='application/ld+json'>
#   {
#   "@context": "http://schema.org",
#    "@type": "PostalAddress",
#     "addressCountry": "Ireland",
#     "addressLocality": "Dublin 12",
#     "streetAddress": " Irish Farm Centre, Bluebell "
#   }
# </script>
#
#
# <script type='application/ld+json'>
# {
#   "@context": "http://schema.org",
#   "@type": "Organization",
#   "name" : "Irish Farmers Journal",
#   "url" : "https://www.farmersjournal.ie/",
#   "logo" : "https://s3-eu-west-1.amazonaws.com/ifj/images/header-logo.png"
#   }
# </script>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <!--Adwords-->
# <!-- Google Code for Remarketing Tag -->
# <!--------------------------------------------------
# Remarketing tags may not be associated with personally identifiable information or placed on pages related to sensitive categories. See more information and instructions on how to setup the tag on: http://google.com/ads/remarketingsetup
# --------------------------------------------------->
# <!--<script type="text/plain" data-cookie-if="analytical">-->
# <script>
# /* <![CDATA[ */
# var google_conversion_id = 984655660;
# var google_custom_params = window.google_tag_params;
# var google_remarketing_only = true;
# /* ]]> */
# </script>
# <div style="display:none">
# <!--<script type="text/plain" data-cookie-if="analytical" src="//www.googleadservices.com/pagead/conversion.js"></script>-->
# <script src="//www.googleadservices.com/pagead/conversion.js"></script>
#
# </div>
# <noscript>
# <div style="display:inline;">
# <img height="1" width="1" style="border-style:none;" alt="" src="//googleads.g.doubleclick.net/pagead/viewthroughconversion/984655660/?value=0&amp;guid=ON&amp;script=0"/>
# </div>
# </noscript>
# <!--END Adwords-->
#
#
#
#
# <!--script type="text/javascript">
# setTimeout(function(){var a=document.createElement("script");
# var b=document.getElementsByTagName("script")[0];
# a.src=document.location.protocol+"//dnn506yrbagrg.cloudfront.net/pages/scripts/0014/4660.js?"+Math.floor(new Date().getTime()/3600000);
# a.async=true;a.type="text/javascript";b.parentNode.insertBefore(a,b)}, 1);
# </script-->
#
# <!--Google Analyitics-->
# <!--<script type="text/plain" data-cookie-if="analytical">-->
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#
# 	ga('create', 'UA-1067584-1', {'alwaysSendReferrer': true}, 'farmersjournal.ie');	ga(function(tracker) {
# 		var originalSendHitTask = tracker.get('sendHitTask');
# 		tracker.set('sendHitTask', function(model) {
#
# 			var payLoad = model.get('hitPayload');
# 			originalSendHitTask(model);
# 			var gifRequest = new XMLHttpRequest();
#
# 			// POST a mirror tag call to the local server
# 			var gifPath = "/mirrorimage/";
# 			gifRequest.open('POST', gifPath + '?' + payLoad, true);
# 			//gifRequest.send(model.get('hitPayload'));
# 		});
# 	});
# 	ga('send', 'pageview');
#
#
#
# </script>
# <!--END Google Analyitics-->
#
#         <link href="/css/introjs.css" rel="stylesheet">
#         <style type="text/css">
#             .ifjIntro .introjs-skipbutton {
#                 color: #da2128;
#                 font-family: Roboto;
#                 font-size: 14px;
#                 font-weight: 700;
#                 text-transform: uppercase;
#                 background: none;
#                 border-color: transparent;
#                 letter-spacing: 0.5px;
#                 float:left;
#             }
#             .ifjIntro .introjs-donebutton {
#                 color: #da2128;
#                 font-family: Roboto;
#                 font-size: 14px;
#                 font-weight: 700;
#                 text-transform: uppercase;
#                 background: none;
#                 border-color: transparent;
#                 letter-spacing: 0.5px;
#                 float:none;
#             }
#             .ifjIntro .introjs-tooltiptext{
#                 color: #000000;
#                 font-family: Roboto;
#                 font-size: 14px;
#                 font-weight: 400;
#                 line-height: 20px;
#                 padding:15px;
#             }
#
# .changeautorenewstate {cursor: pointer;}
#
# .form-container.form-container-2 form input {
#     -webkit-box-shadow: none !important;
#     box-shadow: none !important;
#     border-radius: 0 !important;
#     color: #292121 !important;
#     border-top: 0 !important;
#     border-left: 0 !important;
#     border-right: 0 !important;
#     border-bottom: 1px solid #bdbdbd !important;
# }
#
#
# .form-container.form-container-2 form .input-label {
#     margin: 5px 0 !important;
#     color: #787878 !important;
#     font-size: 13px !important;
#     font-weight: 400 !important;
#     line-height: 13px !important;
#     font-family: Roboto !important;
# }
#
# .form-container.form-container-2 form select {
#     border: transparent !important;
#     border-bottom: 1px solid #bdbdbd  !important;
#     border-radius: 0 !important;
#     -webkit-box-shadow: inset 0 0 0 rgba(0,0,0,.075) !important;
#     box-shadow: inset 0 0 0 rgba(0,0,0,.075) !important;
#     padding-left: 0 !important;
#     -webkit-appearance: none !important;
#     -moz-appearance: none !important;
#     background: url(/images/select-dropdown.png) no-repeat !important;
#     background-position: 100% 5px !important;
#     color: #292121 !important;
# }
#
# ul.label-checkout-list li input+label a {
#     color:white !important;
# }
#
#         </style>
#
# <script>
# window.dataLayer = window.dataLayer || []; // add THIS please too in the first snippet
# dataLayer.push({"membership" : "non-subscriber"});</script>
#
#
#
#
#
#
#     </head>
#
#     <body>
#         <div class="container">
#
#
#
# <style>
#     .fixed-nav-2{
#         float:right; margin-left:40%;
#     }
#
# .left-arrow::before{
#     content:url('/left-red-arrow.png');
# }
#
#
# .mega-dropdown .menu-btn-2 {
#     color: #fff;
#     font-family: Roboto;
#     font-size: 13px;
#     font-weight: 700;
#     text-transform: uppercase;
#     letter-spacing: .19px;
#     position: absolute;
#     bottom: 5px !important;
#     right: 15px;
#     text-decoration: none;
# }
#
# .mega-dropdown .menu-btn-2 span{
#     padding-left: 10px;
# }
#
# .menu-btn{
#     cursor: pointer !important;
# }
#
# .second-menu-btn{
#     cursor: pointer;
# }
#
# .white-link a{
#     color: white !important;
# }
# .white-link {
#     color: white !important;
# }
#
#
# .mobile-code-link{
#     padding-right: 21.5px;
# }
# .mobile-subscribe-using-code{
#     margin-left: 75px;
# }
# .mobile-epaper{
#     padding-left: 65px;
# }
# @media only screen and (max-width: 321px){
#     .mobile-code-link{
#         padding-right: 8.5px;
#     }
#     .mobile-subscribe-using-code{
#         margin-left: 45px !important;
#     }
#     .mobile-epaper{
#         padding-left: 25px;
#     }
# }
#
#
# /* mobile menu */
# .panel-title.panel-title-mobile-header a{
#     font-size: 20px;
#     color: white !important;
# }
# .panel-default .panel-heading.panel-heading-mobile-header{
#     border: none !important;
# }
#
#
#
#
#
# .mega-dropdown-menu-2 {
#     margin: 0 !important;
#     padding: 20px 0 !important;
#     width: 100%  !important;
#     height: 385px !important;
#     background-color: #707070 !important;
#     /*border-color: #372c2c;*/
#     border: 0 !important;
#   /*  border-radius: 0;*/
#     box-shadow: none !important;
#     -webkit-box-shadow: none !important;
# }
# .dropdown-menu-2 {
#     overflow: !important;
#     position: absolute !important;
#     top: 100% !important;
#     left: 0 !important;
#     z-index: 1000 !important;
#     /*display: none;*/
#     float: left !important;
#     min-width: 160px !important;
#     /*padding: 5px 0;
#     margin: 2px 0 0;*/
#     font-size: 14px !important;
#     text-align: left !important;
#     list-style: none !important;
#    /* background-color: #fff;
#     -webkit-background-clip: padding-box;*/
#     /*background-clip: padding-box;*/
#     /*border: 1px solid #ccc;
#     border: 1px solid rgba(0,0,0,.15) !important;*/
#     /*border-radius: 4px;
#     -webkit-box-shadow: 0 6px 12px rgba(0,0,0,.175);
#     box-shadow: 0 6px 12px rgba(0,0,0,.175);*/
# }
#
#
# .mega-dropdown-menu-2 {
#     margin: 0 !important;
#     padding: 20px 0 !important;
#     width: 100% !important;
#     /*height: 800px !important;*/
#     /*background-color: #372c2c !important;*/
#     border-color: #707070 !important;
#    /* border-radius: 0;*/
#     box-shadow: none  !important;
#     -webkit-box-shadow: none !important
# }
# .mega-dropdown-menu-2>li>ul {
#     padding: 0 !important;
#     margin: 0 !important;
#     padding-bottom: 30px !important
# }
# .mega-dropdown-menu-2>li>ul>li {
#     list-style: none !important
# }
# .mega-dropdown-menu-2>li>ul>li>a {
#     display: block !important;
#     color: white !important;
#     font-family: "Coranto 2" !important;
#     font-size: 18px !important;
#     font-weight: 300 !important;
#     line-height: 18px !important;
#     padding: 5px !important
# }
# .mega-dropdown-menu-2>li ul>li>a:focus,
# .mega-dropdown-menu-2>li ul>li>a:hover {
#     text-decoration: none !important
# }
# .mega-dropdown-menu-2 .dropdown-header {
#     padding: 10px 5px !important;
#     color: #fff !important;
#     font-family: "Schadow Blk BT" !important;
#     font-size: 17px !important;
#     font-weight: 400 !important;
#     line-height: 20px !important
# }
#
# .dropdown-header::after {
#     content: url(/right-red-arrow.png);
# }
#
#
#
#
#
# </style>
#
#
#
# <!-- Load Facebook SDK for JavaScript -->
# <div id="fb-root"></div>
#
#
#
#
#
#
#
#
#
#  <!-- mobile -->
#
#
#
#
#
#
#
#                     <nav class="navbar  navbar-default" data-swiftype-index='false' style="max-height: 100px; min-height: 100px"> <!-- style="min-height:50px; max-height: 100px;" -->
#                         <div class="container-fluid" style="padding-left:10px; padding-right:10px">
#                             <div class="navbar-header">
#                                 <a class="navbar-brand" href="https://www.farmersjournal.ie">
#                                         <img src="/images/header-logo.png" style="height:80px; padding-top: 0px; margin-top:-4px;  margin-left:2.5px"/>
#                                 </a>
#
#
# <div class="margin-t-10 search-header-desktop-disable-enable" style="margin-left: 220px;float: left;display: block;width: 400px; display: none">
#                     <!-- google filter -->
#                     <h4 class="panel-title-mobile-header" style="margin-top: 18px">
#                         <style>
#                             .gsc-input-box{
#                                 color:#000;
#                             }
#
#
#                             .gsc-search-box-tools .gsc-search-box .gsc-input {
#                                 padding: 0;
#                             }
#                             .gsc-input-box {
#                                 padding-top: 6px;
#                                 padding-bottom: 5px;
#                                 border-top-left-radius: 8px;
#                                 border-bottom-left-radius: 8px;
#                             }
#                             input.gsc-input, .gsc-input-box, .gsc-input-box-hover, .gsc-input-box-focus {
#                                 border-color: #DFE1E5;
#                             }
#
#                             .gsc-search-button .gsc-search-button-v2 {
#                                 padding-left: 15px;
#                                 margin: 0px;
#                                 height: 40px;
#                                 width: 5px;
#                                 border-top-right-radius: 7px;
#                                 border-bottom-right-radius: 7px;
#                                 margin-bottom: 1px
#                             }
#
#                             .gsc-input-box {
#                                 border: 1px solid #dfe1e5;
#                                 background: #fff;
#                             }
#                         </style>
#                         <!--  type="text/plain" data-cookie-if="analytical" -->
#                         <!--<script async="" src="https://cse.google.com/cse.js?cx=014316877121364955477:zfs3xidicoy"></script>-->
#                         <script async="" src="js/cse-google-com/cse.js?cx=014316877121364955477:zfs3xidicoy"></script>
#                         <div id="___gcse_0"><div class="gsc-control-searchbox-only gsc-control-searchbox-only-en" dir="ltr">
#                             <form action="/archive.php" method="get" id="form-search-st2" class="gsc-search-box gsc-search-box-tools" accept-charset="utf-8"><table cellspacing="0" cellpadding="0" class="gsc-search-box"><tbody><tr><td class="gsc-input"><div class="gsc-input-box" id="gsc-iw-id2"><table cellspacing="0" cellpadding="0" id="gs_id50" class="gstl_50 gsc-input" style="width: 100%; padding: 0px; height: 26px"><tbody><tr><td id="gs_tti50" class="gsib_a"><input autocomplete="off" type="text" size="10" class="gsc-input" name="stq" id="gsc-i-id2" placeholder="Custom Search" dir="ltr" spellcheck="false" style="width: 100%; padding: 0px; border: none; margin: 0px; height: auto; text-indent: 48px; outline: none;"></td><td class="gsib_b"><div class="gsst_b" id="gs_st50" dir="ltr"><a class="gsst_a" href="javascript:void(0)" title="Clear search box" role="button" style="display: none;"><span class="gscb_a" id="gs_cb50" aria-hidden="true">×</span></a></div></td></tr></tbody></table></div></td><td class="gsc-search-button"><button value="Enter" class="gsc-search-button gsc-search-button-v2"><svg width="13" height="13" viewBox="0 0 13 13"><title>search</title><path d="m4.8495 7.8226c0.82666 0 1.5262-0.29146 2.0985-0.87438 0.57232-0.58292 0.86378-1.2877 0.87438-2.1144 0.010599-0.82666-0.28086-1.5262-0.87438-2.0985-0.59352-0.57232-1.293-0.86378-2.0985-0.87438-0.8055-0.010599-1.5103 0.28086-2.1144 0.87438-0.60414 0.59352-0.8956 1.293-0.87438 2.0985 0.021197 0.8055 0.31266 1.5103 0.87438 2.1144 0.56172 0.60414 1.2665 0.8956 2.1144 0.87438zm4.4695 0.2115 3.681 3.6819-1.259 1.284-3.6817-3.7 0.0019784-0.69479-0.090043-0.098846c-0.87973 0.76087-1.92 1.1413-3.1207 1.1413-1.3553 0-2.5025-0.46363-3.4417-1.3909s-1.4088-2.0686-1.4088-3.4239c0-1.3553 0.4696-2.4966 1.4088-3.4239 0.9392-0.92727 2.0864-1.3969 3.4417-1.4088 1.3553-0.011889 2.4906 0.45771 3.406 1.4088 0.9154 0.95107 1.379 2.0924 1.3909 3.4239 0 1.2126-0.38043 2.2588-1.1413 3.1385l0.098834 0.090049z"></path></svg></button></td><td class="gsc-clear-button"><div class="gsc-clear-button" title="clear results">&nbsp;</div></td></tr></tbody></table>
#                             </form></div></div>
#
#
# <!--                        <script async src="https://cse.google.com/cse.js?cx=014316877121364955477:zfs3xidicoy"></script>
#                         <div class="gcse-search"></div>-->
#
#                     </h4>
#                     <!-- google filter -->
#
#                 </div>
#
#
#
#                             </div>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <div class="top-sub-menu" style="padding-top:0px; display: contents;">
#             <span id="links-menu-header">
#              <!-- not logged -->
#
#
#                     <div class="sub-menu-item" style="padding-top:4px; padding-bottom:3px; padding-left: 15px; font-size: 15px"><a href="#" class="white-link linkLogin">SIGN IN</a></div> <!-- linkLogin -->
#                                         <div class="sub-menu-item" style="padding-bottom: 3px; padding-top: 4px; background-color: #70C2B4; padding-left: 10px; padding-right: 10px; margin-left: 10px;  font-size: 15px"><a href="#" class="white-link use-the-code">USE PAPER CODE</a></div>
#                                         <div style="background-color: #FFFF00; padding-top:4px; padding-bottom:3px; padding-left:15px; padding-right:15px;  font-size: 15px" class="sub-menu-item"><a class="black" href="https://www.farmersjournal.ie/subscribe.php">SUBSCRIBE</a></div>
#
#
#                 </span><div class="sub-menu-item desktop-header-search-button" id="desktop-icon-search" style="padding-top:5px; font-size: 15px; margin-right: 10px"><a class="white-link" href="#">SEARCH<i class="fa fa-search margin-l-10" aria-hidden="true"></i></a></div>        </div>
#
#
#
#
#
#
#
#
#
#
#
#
#                 <div id="main-mega-dropdown" class="dropdown mega-dropdown">
#             <a href="/archive.php" class="mobile-show search-btn"><i id="search-icon" class="fa fa-search fa-2" aria-hidden="true"></i></a>
#
#             <div class="right menu-btn-2  header-channel-links" style="margin-right:37px; bottom: 0px">
#
#                 <span>
#                     <a class="white-link" href="/farming-news/beef/54"> BEEF </a>
#                 </span>
#
#                 <span>
#                     <a class="white-link" href="/farming-news/dairy/55"> DAIRY</a>
#                 </span>
#
#                 <span>
#                     <a class="white-link" href="/farming-news/sheep/56"> SHEEP </a>
#                 </span>
#
#                 <span>
#                     <a class="white-link" href="/farming-news/agribusiness-news/58"> AGRIBUSINESS </a>
#                 </span>
#
#                 <span>
#                     <a class="white-link" href="/farming-news/machinery/59"> MACHINERY </a>
#                 </span>
#
#                 <span>
#                     <a class="white-link" href="/farm/tillage/57"> TILLAGE </a>
#                 </span>
#
#                 <span>
#                     <a class="white-link" href="/farm/pedigree/320"> PEDIGREE </a>
#                 </span>
#
#                 <span>
#                     <a class="white-link" href="/farm/buildings/315"> BUILDINGS </a>
#                 </span>
#
#                 <span>
#                     <a class="white-link" href="/farm/property/76"> PROPERTY </a>
#                 </span>
#
#                 <span>
#                     <a class="white-link" href="/hub"> KNOWLEDGE HUB</a>
#                 </span>
#
#                 <span>
#                     <a class="white-link" href="/farming-news/irish-country-living/3"> IRISH COUNTRY LIVING </a>
#                 </span>
#
#             </div>
#
#
#
#
#             <a class="dropdown-toggle right menu-btn menu-btn-action" style="bottom: 5px; right:10px">
#                 <i id="menu-icon" class="fa fa-bars fa-2 header-desktop-icon" aria-hidden="true"></i>
#             </a>
#             <ul class="dropdown-menu mega-dropdown-menu dropdown-menu-2 mega-dropdown-menu-2" id="html-menu-desktop-header" data-swiftype-index='false'>
#
#
#                     <!-- desktop menu top -->
#                     <!-- this content is being provided by id="html-menu-desktop-footer" , file includes/footer.php-->
#                     <!-- also happening in id="html-menu-desktop-scrool" -->
#                     <!-- the command to do this is in js/ifj.js-->
#
#                             </ul>
#         </div>
#
#
#
#     </div>
#        <!-- will be delete when the footer menu is live -->
# <!--        <div id="main-mega-dropdown" class="dropdown mega-dropdown">
#             <a href="/archive.php" class="mobile-show search-btn"><i id="search-icon" class="fa fa-search fa-2" aria-hidden="true"></i></a>
#             <a class="dropdown-toggle right menu-btn"><span>Menu</span> <i id="menu-icon" class="fa fa-bars fa-2" aria-hidden="true"></i></a>
#
#         </div>-->
#         <!-- will be delete when the footer menu is live -->
# </nav>
#
#
# <header class="nav-down display-none">
#     <div class="left scroll-left-box"><a href="/"><i class="fa fa-home fa-4" aria-hidden="true"></i><span>HOME</span></a></div>
#     <div class="right scroll-right-box">
#         <a href="archive.php" class="desktop-header-search-button"><i class="fa fa-search margin-l-10" aria-hidden="true"></i><span>SEARCH</span></a><!--/archive.php-->
#         <span style="background-color: #FFFF00; margin-top:7px; padding-top:5px; padding-bottom:5px; padding-left:15px; margin-left:30px; padding-right:15px" class="sub-menu-item"><a class="black" href="https://www.farmersjournal.ie/subscribe.php">SUBSCRIBE</a></span><span class='use-the-code'><a href='#' class='white-link'>USE PAPER CODE</a></span><a class="white-link linkLogin"><span>SIGN IN</span></a>
#
#
#         <a class="dropdown-toggle second-menu-btn">
#             <span></span>
#             <i class="fa fa-2 fa-bars" id="second-menu-btn-icon" open="true" aria-hidden="true"></i>
#             <i class="fa fa-2 fa-times" id="second-menu-btn-icon-x" aria-hidden="true" style="display: none"></i>
#
#         </a>
#
#
#
#
#
#
#         <div id="" class="second-dropdown mega-dropdown test"> <!-- desktop menu scrool  -->
#
#
#
#                     <ul class="dropdown-menu mega-dropdown-menu dropdown-menu-2 mega-dropdown-menu-2" id="html-menu-desktop-scrool" style="height: 425px !important;">
#                     <!-- desktop menu scrool -->
#                     <!-- this content is being provided by id="html-menu-desktop-footer" , file includes/footer.php-->
#                     <!-- also happening in id="html-menu-desktop-scrool" -->
#                     <!-- the command to do this is in js/ifj.js-->
#                     </ul>
#
#
#
#
#
#         </div>
#
#     </div>
# </header>
#
#
#
#
#
#
#
# <style type="text/css">
#
# .modalRedeemCode .modal-dialog .modal-content {
#     width: 1300px;
#     display: block;
#     margin: 0px auto;
#     border-radius: 0px;
#     background-color: #da2128;
# }
#
# .modalRedeemCode .close{
#     float: right;
#     font-size: 21px;
#     font-weight: 700;
#     line-height: 1;
#     color: #000;
#     text-shadow: 0 1px 0 #fff;
#     opacity: 1;
# }
#
# .modalRedeemCode .bigtitle {
#     color: #ffffff;
#    /* font-family: "Roboto, Regular";*/
#     font-size: 18px;
#   /*font-weight: 700;*/
#     line-height: 42px;
# }
#
# .modalRedeemCode .smalltitle {
#     color: #ffffff;
#    /* font-family: "Roboto, Regular";*/
#     font-size: 16px;
#     line-height: 20px;
#     text-align: center;
#     width: 90%;
#     margin: 0px auto;
# }
#
#
# .redeem_code_btn_unlock {
#     background-color: #70C2B4;
# }
#
#
# /* rewriting same the originals attributes */
# /*.label-text {
#     color: #f0f0f0 !important;
#     padding: 0 30px !important;
#     font-size: 18px !important;
#     margin-top: 6px !important;
# }*/
#
# .label-text-2 {
#     color: #f0f0f0 !important;*/
#     padding: 0 30px !important;
#     font-size: 18px !important;
#     margin-top: 6px !important;
#     font-family: Roboto;
#     font-weight: 500;
# /*    display: inline-block;*/
#     display: block;
#     position: relative;
#     cursor: pointer;
#     padding: 0 10px;
#     /* border: 1px solid #787878; */
#     border-radius: 100px;
#     margin-right: 3px;
#     height: 38px;
#
# }
#
# .inputRedeemCode{
#     border-top:0px;
#     border-left:0px;
#     border-right:0px;
#     border-bottom: 2px solid black;
#     background-color:#da2128;
#     margin:2px;
#     text-align: center;
#     width: 30px;
#     outline-color: transparent;
#     outline-style: none;
# }
# </style>
#
#
# <div class="modal fade modalRedeemCode" id="modalRedeemCode" tabindex="-1" role="dialog" aria-labelledby="modalRedeemCodeLabel" aria-hidden="true" style="z-index:99999" data-swiftype-index="false">
#
#     <div class="modal-dialog">
#
#     <div class="modal-content" style="width: 80% !important;"> <!--  modal_article_footer -->
#
#       <!-- Modal Header -->
#       <div class="modal-header">
#           <button type="button" class="close" data-dismiss="modal">
#                  <span aria-hidden="true" class=""><img src="/images/modal_close_x.png"></span>
#                  <span class="sr-only">Close</span>
#           </button>
#       </div>
#
#
#
#
#                 <div  class="row">
#                     <div class="col-12">
#
#
#                         <p style="text-align: center; padding:10px" class="bigtitle padding-b-1"><img width="148px" src="/images/header-logo.png"></p>
#
#                         <p style="text-align: center; padding:10px" class="bigtitle padding-b-1">ENTER YOUR LOYALTY CODE:</p>
#
#
#                         <p style="text-align: center; padding:20px" class="smalltitle">
#                             <input class="inputRedeemCode inputRedeemCode_1" id="inputRedeemCode_1" autocomplete="off" type="text" size="3" maxlength="1" name="inputRedeemCode_1" autofocus>
#                             <input class="inputRedeemCode inputRedeemCode_2" id="inputRedeemCode_2" autocomplete="off" type="text" size="3" maxlength="1" name="inputRedeemCode_2">
#                             <input class="inputRedeemCode inputRedeemCode_3" id="inputRedeemCode_3" autocomplete="off" type="text" size="3" maxlength="1" name="inputRedeemCode_3">
#                             <input class="inputRedeemCode inputRedeemCode_4" id="inputRedeemCode_4" autocomplete="off" type="text" size="3" maxlength="1" name="inputRedeemCode_4">
#                             <input class="inputRedeemCode inputRedeemCode_5" id="inputRedeemCode_5" autocomplete="off" type="text" size="3" maxlength="1" name="inputRedeemCode_5">
#                             <input class="inputRedeemCode inputRedeemCode_6" id="inputRedeemCode_6" autocomplete="off" type="text" size="3" maxlength="1" name="inputRedeemCode_6">
#                         </p>
#
#                         <p style="text-align: center; padding:0px" class="smalltitle">
#                             <div align="center">
#                                 <ul class="label-checkout-list">
#                                     <li style="padding: 0px;border-radius: 15px;" class="">
#                                         <label class="redeem_code_btn_unlock"><div class="label-text-2 unlockbtncde" mtype="modalRedeemCode">UNLOCK</div></label>
#                                     </li>
#                                 </ul>
#                            </div>
#                         </p>
#
#                         <p style="text-align: center; padding:20px" class="smalltitle">
#                             The reader loyalty code gives you full access to the site from when you enter it until the following Wednesday at 9pm. Find your unique code on the back page of Irish Country Living every week.
#                         </p>
#
#
#
#                     </div>
#
#                </div>
#
#     </div>
#     </div>
#
# </div>
#
# <div class="modal fade modalRedeemCode" id="modalRedeemCode_Success" tabindex="-1" role="dialog" aria-labelledby="modalRedeemCode_SuccessLabel" aria-hidden="true" style="z-index:1999" data-swiftype-index="false">
#
#     <div class="modal-dialog" id="rfclicker">
#
#     <div class="modal-content" style="width: 80% !important;"> <!-- modal_article_footer -->
#
#       <!-- Modal Header -->
#       <div class="modal-header">
#           <button type="button" class="close" data-dismiss="modal">
#                  <span aria-hidden="true" class="white">&times;</span>
#                  <span class="sr-only">Close</span>
#           </button>
#       </div>
#
#                 <div  class="row">
#                     <div class="col-12">
#
#
#                         <p style="text-align: center; padding:10px" class="bigtitle padding-b-1"><img width="148px" src="/images/header-logo.png"></p>
#
#                         <p style="text-align: center; padding:10px" class="bigtitle padding-b-1">CODE ACCEPTED</p>
#                         <!-- <p style="text-align: center; padding:20px" class="smalltitle"> -->
#                             <div align="center" style="padding:10px">
#                                 <img src="/images/green_code_success.png" id="successbuttonimg">
#                            </div>
#                         <!-- </p> -->
#                         <p style="text-align: center; padding:20px" class="smalltitle">
#                             You have full access to farmersjournal.ie on this browser until 9pm next Wednesday. Thank you for buying the paper and using the code.
#                         </p>
#
#
#
#                     </div>
#
#                </div>
#
#     </div>
#     </div>
#
# </div>
#
# <div class="modal fade modalRedeemCode" id="modalRedeemCode_Declined" tabindex="-1" role="dialog" aria-labelledby="modalRedeemCode_DeclinedLabel" aria-hidden="true" style="z-index:1998" data-swiftype-index="false">
#
#     <div class="modal-dialog">
#
#     <div class="modal-content" style="width: 80% !important;"> <!-- modal_article_footer -->
#
#       <!-- Modal Header -->
#       <div class="modal-header">
#           <button type="button" class="close" data-dismiss="modal">
#                  <span aria-hidden="true" class="white">&times;</span>
#                  <span class="sr-only">Close</span>
#           </button>
#       </div>
#
#                 <div  class="row">
#                     <div class="col-12">
#
#                         <div align="center" style="padding:10px">
#                             <img src="/images/black_code_declined.png">
#                         </div>
#
#                         <p style="text-align: center" class="bigtitle padding-b-1">CODE NOT VALID</p>
#                         <p style="text-align: center" class="smalltitle">
#                             Please try again or contact us.
#                         </p>
#                         <p style="text-align: center; padding:20px" class="smalltitle">
#                             <input class="inputRedeemCode dinputRedeemCode_1" id="inputRedeemCode_1_Declined" autocomplete="off" type="text" size="3" maxlength="1" name="inputRedeemCode_1">
#                             <input class="inputRedeemCode dinputRedeemCode_2" id="inputRedeemCode_2_Declined" autocomplete="off" type="text" size="3" maxlength="1" name="inputRedeemCode_2">
#                             <input class="inputRedeemCode dinputRedeemCode_3" id="inputRedeemCode_3_Declined" autocomplete="off" type="text" size="3" maxlength="1" name="inputRedeemCode_3">
#                             <input class="inputRedeemCode dinputRedeemCode_4" id="inputRedeemCode_4_Declined" autocomplete="off" type="text" size="3" maxlength="1" name="inputRedeemCode_4">
#                             <input class="inputRedeemCode dinputRedeemCode_5" id="inputRedeemCode_5_Declined" autocomplete="off" type="text" size="3" maxlength="1" name="inputRedeemCode_5">
#                             <input class="inputRedeemCode dinputRedeemCode_6" id="inputRedeemCode_6_Declined" autocomplete="off" type="text" size="3" maxlength="1" name="inputRedeemCode_6">
#                         </p>
#
#                         <p style="text-align: center; padding:0px" class="smalltitle">
#                             <div align="center">
#                                 <ul class="label-checkout-list">
#                                     <li style="padding: 0px;border-radius: 15px;" class="">
#                                         <label class="redeem_code_btn_unlock"><div class="label-text-2 unlockbtncde" mtype="modalRedeemCode_Declined">UNLOCK</div></label>
#                                     </li>
#                                 </ul>
#                            </div>
#                         </p>
#
#                         <p style="text-align: center; padding:20px" class="smalltitle">
#                             For assistance, call 01 4199525<br>
#                             or email subs@farmersjournal.ie
#                         </p>
#
#                    		<p style="text-align: center; padding:20px" class="smalltitle">
#                             <a href="/code"> Read about how the code works here </a>
#                         </p>
#
#                     </div>
#
#                </div>
#
#     </div>
#     </div>
#
# </div>
#
#
# <script type="text/javascript">
#
#             $( document ).ready(function() {
#
#
#                 $('#successbuttonimg').css( 'cursor', 'pointer' );
#
#                 $( ".use-the-code" ).click(function(){
#
#
#                     //$('#modalSignIn').html("-");// to avoid conflict between modals qwhen user press "ENTER"
#                     $('.email-login-form').prop("class", "email-login-form-off");
#
#                     $('#modalSignInResetPassword-failed').modal('hide');
#
#
#                     $('#modalRedeemCode').modal('show');
#                     setTimeout(function (){
#                         $('#inputRedeemCode_1').focus();
#                     }, 1000);
#
#                 });
#
#
#
#                 $(document).keydown(function(e) {//simulate the click on enter press also here
#
#
#                 	if ($("#modalRedeemCode").hasClass('in') && (e.keyCode == 13 || e.which == 13)) {
#               	    	//alert("Enter is pressed");
#               	    	dounlockbtncde("modalRedeemCode");
#               	    }
#                 	if ($("#modalRedeemCode_Declined").hasClass('in') && (e.keyCode == 13 || e.which == 13)) {
#               	    	//alert("Enter is pressed");
#               	    	dounlockbtncde("modalRedeemCode_Declined");
#               	    }
#
#
#                     if(  ($("#modalRedeemCode").hasClass('in') && (e.keyCode == 8 || e.which == 8)) || ($("#modalRedeemCode_Declined").hasClass('in') && (e.keyCode == 8 || e.which == 8)) ){
#
#                         $("input:focus").val("");
#                         $("input:focus").prev().focus();
#                         console.log($("input:focus"));
#                     }
#
#
#
#                     if ($("#main-mega-dropdown").hasClass('open') && (e.keyCode == 13 || e.which == 13)) {
#                         //alert("Enter is pressed");
#                         console.log("Enter is pressed for search");
#
#                         if ($("#gsc-i-id1").is(":focus")) {
#                             $( "#form-search-st1" ).submit();
#                         }
#                         if ($("#gsc-i-id2").is(":focus")) {
#                             $( "#form-search-st2" ).submit();
#                         }
#
#
#
#                     }
#
#
#               	});
#
#
#
#
#
#
#
#
#                   	function dounlockbtncde(modalclicked){
#
#
# 						if(modalclicked=='modalRedeemCode'){
#                                         var d1 = $('.inputRedeemCode_1').val();
#                                         var d2 = $('.inputRedeemCode_2').val();
#                                         var d3 = $('.inputRedeemCode_3').val();
#                                         var d4 = $('.inputRedeemCode_4').val();
#                                         var d5 = $('.inputRedeemCode_5').val();
#                                         var d6 = $('.inputRedeemCode_6').val();
# 										var loyaltycode = d1 + d2 + d3 + d4 + d5 + d6;
#             			}
#
# 						if(modalclicked=='modalRedeemCode_Declined'){
#                                         var d1 = $('.dinputRedeemCode_1').val();
#                                         var d2 = $('.dinputRedeemCode_2').val();
#                                         var d3 = $('.dinputRedeemCode_3').val();
#                                         var d4 = $('.dinputRedeemCode_4').val();
#                                         var d5 = $('.dinputRedeemCode_5').val();
#                                         var d6 = $('.dinputRedeemCode_6').val();
# 										var loyaltycode = d1 + d2 + d3 + d4 + d5 + d6;
#             			}
#
#                         var jstring = 'https://api.farmersjournal.ie/v1/codecoupon/code_login2019new.php?loyaltycode='+ loyaltycode;
#                         //alert(loyaltycode);
# ...
#                 $('.filtermailchimpclick').on('click', function() {
#
#                     var nameclicked = $(this).attr('name');
#                     var currentchecked = $(this).prop('checked');
#
#
#                     var actionc = '';
#                     if (currentchecked == true) {
#                         //$(this).attr('apmcheck', 'notchecked');
#                         actionc = '1'; //add
#                     } else {
#                         //$(this).attr('apmcheck', 'checked');
#                         actionc = '0'; //false
#                     }
#
#
#                     //alert(nameclicked + " " + currentchecked + " " + actionc);
#                     var emailmailchimppass = '';
#
#
#                     var jstring = 'https://api.farmersjournal.ie/v1/mailchimp/update_mailchimp_list.php?email=' + emailmailchimppass + '&group_id=' + nameclicked + '&status=' + actionc;
#                     //console.log(jstring);
#
#                     $.getJSON(jstring, function(data) {
#                         //console.log(data);
#                         //var registerresponse = data['fjapp'][0]['api'][0]['response'];//should be done
#                         //var query = data['fjapp'][0]['api'][0]['query'];//should be done
#                         //console.log(registerresponse);
#                         //console.log(query);
#
#                     });
#
#
#                 });
#             }
#             //end of MAILCHIMP POPULATE
#
#
#
#             //save-btn-em-interests on click by Aidan
#
#             $('#save-btn-em-interests').on('click', function() {
#
#                 var tokenid = '';
#
#                 var emailP = $('#emailP').val();
#                 var customernameP = $('#customernameP').val();
#                 var countyP = $('#countyP').val();
#
#                 var jstring = 'https://api.farmersjournal.ie/v1/membershipsettings/updateformclick.php?emailP=' + emailP + '&customernameP=' + customernameP + '&countyP=' + countyP + '&tokenid=' + tokenid;
#                 //console.log(jstring + " | " + emailP + " " + customernameP + " " + countyP);
#
#
#
#                 $.getJSON(jstring, function(data) {
#                     //console.log(data);
#                     var registerresponse = data['fjapp'][0]['api'][0]['response']; //should be done
#
#                     var fname = data['fjapp'][0]['api'][0]['fname'];
#                     var lname = data['fjapp'][0]['api'][0]['lname'];
#                     var coutyp = data['fjapp'][0]['api'][0]['countyp'];
#
#                     //reset the cookies here
#                     Cookies.set('ifjfname', fname, { expires: 365 });
#                     Cookies.set('ifjlname', lname, { expires: 365 });
#                     Cookies.set('ifjrid', coutyp, { expires: 365 });
#
#                     window.location = '/myjournal/editinterests';
#                 });
#
#
#             });
#
#             //end of save button email interests
#
#
#
#
#             //save-btn-em-SETTINGS on click
#
#             $('#save-btn-em-settings').on('click', function() {
#
#                 var tokenid = '';
#                 var nameS = $('#nameS').val();
#                 var emailS = $('#emailS').val();
#                 var phoneS = $('#phoneS').val();
#                 var passwordS = $('#passwordS').val();
#
#                 //alert(tokenid + " =tokenid " + nameS + " =nameS " + emailS + " =emailS " + phoneS + " =phoneS " + passwordS + " =passwordS ");
#
#
#                 var jstring = 'https://api.farmersjournal.ie/v1/membershipsettings/updatesettingsclick.php?tokenid=' + tokenid + '&nameS=' + nameS + '&emailS=' + emailS + '&phoneS=' + phoneS + '&passwordS=' + passwordS;
#
#
#
#                 $.getJSON(jstring, function(data) {
#                     //console.log(data);
#                     var registerresponse = data['fjapp'][0]['api'][0]['response']; //should be done
#
#                     var fname = data['fjapp'][0]['api'][0]['fname'];
#                     var lname = data['fjapp'][0]['api'][0]['lname'];
#                     var phone = data['fjapp'][0]['api'][0]['phone'];
#                     //var query = data['fjapp'][0]['api'][0]['query'];
#                     //alert(query);
#
#                     //reset the cookies here
#                     Cookies.set('ifjfname', fname, { expires: 365 });
#                     Cookies.set('ifjlname', lname, { expires: 365 });
#                     Cookies.set('ifphone', phone, { expires: 365 });
#
#                     //alert("Thank you. Details updated");
#                     //window.location = '/myjournal/settings';
#                     $('#nameS').val(fname + " "+lname);
#                     $('#emailS').val(emailS);
#                     $('#phoneS').val(phoneS);
#                     $('.feedback').text("Your details have been updated");
#
#                 });
#
#
#
#             });
#
#             //end of save button SETTINGS interests
#
#
#
#
#
#             //save-btn-em-storedcard on click
#
#             $('#save-btn-em-storedcard').on('click', function() {
#
#                 var tokenid = '';
#                 var fname = '';
#                 var lname = '';
#                 var email = '';
#
#                 var cardname = $('#cardname').val();
#                 var cardtype = $('#cardtype').val();
#                 var cardnumber = $('#cardnumber').val();
#                 var expmonth = $('#expmonth').val();
#                 var expyear = $('#expyear').val();
#                 var cvv = $('#cvv').val();
#
# 				var jstring = 'https://api.farmersjournal.ie/v1/membershipsettings/updatestoredcardclick.php?tokenid=' + tokenid + '&fname=' + fname + '&lname=' + lname + '&email=' + email + '&cardname=' + cardname + '&cardtype=' + cardtype + '&cardnumber=' + cardnumber  + '&expmonth=' + expmonth  + '&expyear=' + expyear  + '&cvv=' + cvv;
# 				$.getJSON(jstring, function(data) {
#                     var feedback = data['fjapp'][0]['api'][0]['feedback']; //should be done
# 					//alert(feedback + " .Refreshing your account details to confirm.");
#                     alert(feedback);
#                     window.location = '/myjournal/settings';
#
#                     //$('.feedbackARP').text(feedback);
#                     //$('#introtxtprenewblurb').text("");
#
#                 });
#
#
#
#             });
#
#             //end of save button storedcard
#
#
#
#
#
#
#             //change autorenew state
#
#             $('.changeautorenewstate').on('click', function() {
#
#                 //alert("clicked");
#                 var tokenid = '';
#                 var aon = $(this).attr("aon");
#                 var aonID = $(this).attr("aonID");
#                 //alert(aon + " is aon and aonID is " + aonID);
#
# 				var jstring = 'https://api.farmersjournal.ie/v1/membershipsettings/updateautorenewclick.php?tokenid=' + tokenid + '&aon=' + aon + '&aonID=' + aonID;
# 				$.getJSON(jstring, function(data) {
#                     var response = data['fjapp'][0]['api'][0]['response']; //should be done
#
# 					alert("Thank you. Details updated. Refreshing your account details.");
#                     //var reswindow = encodeURIComponent('/myjournal/settings#mysubs');
#                     window.location = '/myjournal/settings';
#                 });
#
#
#
#             });
#
#             //end of change autorenew state
#
#
#
#
#
#             //MEMBERSDHIP MPODAL OPTIONS
#             $('.back-line').on('click', function() {
#                 $('#cancelModal').modal('hide'); //Oops, take me back to settings
#             });
#
#
#             $('#cancelmembership').on('click', function() {
#                 //alert("cancelling membership") //Cancel membership - Your membership will be cancelled but we’ll still retain your data incase you want to join again in the future, with all the same settings
#                 var jstring = 'https://api.farmersjournal.ie/v1/membershipsettings/cancelmembership.php?action=cancel&tokenid=' + tokenid;
#                 $.getJSON(jstring, function(data) {
#                     var registerresponse = data['fjapp'][0]['api'][0]['response'];
#                     if (registerresponse == 'done') {
#                         alert("Thank you. Your membership has now been cancelled.");
#                         window.location = '/logout.php';
#                     } else {
#                         alert("Sorry, something went wrong, please contact support");
#                     }
#                 });
#
#             });
#
#
#
#
#             $('#deletemembership').on('click', function() {
#                 var jstring = 'https://api.farmersjournal.ie/v1/membershipsettings/cancelmembership.php?action=delete&tokenid=' + tokenid;
#                 $.getJSON(jstring, function(data) {
#                     var registerresponse = data['fjapp'][0]['api'][0]['response'];
#                     if (registerresponse == 'done') {
#                         alert("Thank you. All of your data has been deleted.");
#                         window.location = '/logout.php';
#                     } else {
#                         alert("Sorry, something went wrong, please contact support");
#                     }
#                 });
#
#             });
#
#             $('#callmembership').on('click', function() {
#                 //alert("call us now re membership") //call us now
#                 window.location.href = "tel://00353860115436";
#             });
#
#
#             $('.add-to-collection').on('click', function() {
#             	var collectionID = $(this).attr('rel-cid');
#             	var cid = $(this).attr('rel-token');
#             	var storyID = $('#selectStoryID').val();
#
#             	var jstring = 'https://api.farmersjournal.ie/v1/collections/addtocollection.php?storyid='+storyID+'&cid=' +cid+'&collectionid='+collectionID;
#                 $.getJSON(jstring, function(data) {
#                     if(data['fjapp'][0]['api'][0]['registerresponse'] == "1") {
#
#                         //alert("This article has been saved");
#
#
#
#                            $('#savetoCollectionModalPopupSaved').modal();
#                             $('#savetoCollectionModal').modal('hide');
#
#                     	//window.location.href = "/myjournal/collection/"+data['fjapp'][0]['api'][0]['collectionid'];
#
#                     }else{
#                            // alert("This article has already been saved");
#                             $('#savetoCollectionModalPopup').modal();
#                         }
#                 });
#             });
#
#
#             $( "#selectedCollection" ).change(function() {
#             	var collectionID = $("#selectedCollection option:selected").attr('rel-cid');
#             	var cid = $("#selectedCollection option:selected").attr('rel-token');
#             	var storyID = $('#selectStoryID').val();
#             	var jstring = 'https://api.farmersjournal.ie/v1/collections/addtocollection.php?storyid='+storyID+'&cid=' +cid+'&collectionid='+collectionID;
#             	// var jstring = 'https://api.farmersjournal.ie/v1/collections/addtocollection.php?storyid='+storyID+'&cid=' +cid+'&collectionid='+collectionID;
#                 $.getJSON(jstring, function(data) {
#                     if(data['fjapp'][0]['api'][0]['registerresponse'] == "1") {
#                     	// window.location.href = "/myjournal/collection/"+data['fjapp'][0]['api'][0]['collectionid'];
#                         $('#savetoCollectionModalPopupSaved').modal();
#
#                           $('#savetoCollectionModal').modal('hide');
#                           $('#savetoCollectionModal').removeData();
#                     }else{
#                             //alert("This article has already been saved");
#                             $('#savetoCollectionModalPopup').modal();
#                         }
#
#                 });
# 			});
#             //END OF MEMBERSHIP MODAL OPTIONS
#
#
#
#
#
#
#
#         });
#         </script>
#         <script type="text/javascript" src="/js/intro.js"></script>
#         <script type="text/javascript">
#             var intro = introJs();
#             intro.setOptions({'showStepNumbers': false, 'showBullets': false, 'doneLabel': 'GOT IT, THANKS','tooltipClass': 'ifjIntro',
#             steps: [
#                 {
#                     //element: document.querySelector('#topic-item'),
#                     element: document.querySelector('.step-newsfeed'),
#                     intro: "Browse latest articles for your chosen topics in the Newsfeed"
#                 },
#                 {
#                     element: document.querySelector('.step-editinterests'),
#                     intro: "Follow topics and journalists here to show up in your My Journal feed"
#                 },
#
#                 /*{
#                     element: document.querySelector('.step-deleteinterest'),
#                     intro: "Unfollow topic here"
#                 },*/
#                 {
#                     element: document.querySelector('#search-item'),
#                     intro: "Search for addtional topics or journalists here"
#                 },
#                 {
#                     element: document.querySelector('.step-collection'),
#                     intro: "Save your favourite articles in to Collections"
#                 },
#
#                 {
#                     element: document.querySelector('.step-create-collection'),
#                     intro: "Create a Collection here"
#                 },
#                 {
#                     element: document.querySelector('.step-collection-list-item'),
#                     intro: "You can save articles while browsing the site or select a collection to edit it"
#                 },
#                 {
#                     element: document.querySelector('.step-settings'),
#                     intro: "Here you can edit your membership or account settings"
#                 }
#             ]
#             });
#
#
#
#
#
#             if(Cookies.get('onboardcomplete') != 1) {
#                 intro.start();
#                 intro.onchange(function(targetElement) {
#                     if(this['_direction'] === "forward") {
#                         switch(this['_currentStep']){
#                             case 0:
#                                 $('.step-newsfeed').tab('show');
#                             break;
#                             case 1:
#                                 $('.step-editinterests').tab('show');
#                             break;
#                             case 3:
#                                 $('#search-item a').tab('show');
#                             break;
#                             case 4:
#                                 $('.step-collection').tab('show');
#                             break;
#                             case 7:
#                                 $('.step-settings').tab('show');
#                             break;
#                         }
#                     } else {
#                         console.log(this['_currentStep']);
#                         switch(this['_currentStep']){
#                             case 0:
#                                 $('.step-newsfeed').tab('show');
#                             break;
#                             case 2:
#                                 $('#topic-item a').tab('show');
#                             break;
#                             case 3:
#                                 $('.step-editinterests').tab('show');
#                             break;
#                             case 6:
#                                 $('.step-collection').tab('show');
#                             break;
#                         }
#                     }
#
#                 });
#                 intro.onexit(function() {
#                     Cookies.set('onboardcomplete', 1, { expires: 365 });
#                 });
#                 intro.oncomplete(function() {
#                     Cookies.set('onboardcomplete', 1, { expires: 365 });
#                 });
#                 /*$('.introjs-skipbutton').click(function(){
#                     Cookies.set('onboardcomplete', 1, { expires: 365 });
#                 })*/
#             }
#         </script>
#             </body>
#
#     </html>

# %%
doc = BeautifulSoup(r.text, 'html.parser')
cattle = doc.find_all(text="cattle")
#doc.prettify()

# %%
from scrapy.crawler import CrawlerProcess
import scrapy

# %%
class MySpider(scrapy.Spider):
    name = 'myspider'

    def start_requests(self):
        return [scrapy.FormRequest("https://www.farmersjournal.ie/",
                                   formdata={'user': 'sba19035@student.cct.ie', 'pass': 'lucan123'},
                                   callback=self.logged_in)]

    def logged_in(self, response):
        # here you would extract links to follow and return Requests for
        # each of them, with another callback
        pass
    
    def start_requests(self):
        yield scrapy.Request(f'https://www.farmersjournal.ie/myjournal/newsfeed/{self.category}')

# %%
#process = CrawlerProcess()
process.crawl(MySpider, category="cattle")
# Out:
# 2022-05-08 12:39:41 [scrapy.crawler] INFO: Overridden settings:
# {}
# ---------------------------------------------------------------------------
# ReactorAlreadyInstalledError              Traceback (most recent call last)
# Input In [71], in <cell line: 2>()
#       1 #process = CrawlerProcess()
# ----> 2 process.crawl(MySpider, category="cattle")
#
# File C:\ProgramData\Anaconda3\envs\pycarot\lib\site-packages\scrapy\crawler.py:205, in CrawlerRunner.crawl(self, crawler_or_spidercls, *args, **kwargs)
#     201 if isinstance(crawler_or_spidercls, Spider):
#     202     raise ValueError(
#     203         'The crawler_or_spidercls argument cannot be a spider object, '
#     204         'it must be a spider class (or a Crawler object)')
# --> 205 crawler = self.create_crawler(crawler_or_spidercls)
#     206 return self._crawl(crawler, *args, **kwargs)
#
# File C:\ProgramData\Anaconda3\envs\pycarot\lib\site-packages\scrapy\crawler.py:238, in CrawlerRunner.create_crawler(self, crawler_or_spidercls)
#     236 if isinstance(crawler_or_spidercls, Crawler):
#     237     return crawler_or_spidercls
# --> 238 return self._create_crawler(crawler_or_spidercls)
#
# File C:\ProgramData\Anaconda3\envs\pycarot\lib\site-packages\scrapy\crawler.py:313, in CrawlerProcess._create_crawler(self, spidercls)
#     311 if isinstance(spidercls, str):
#     312     spidercls = self.spider_loader.load(spidercls)
# --> 313 return Crawler(spidercls, self.settings, init_reactor=True)
#
# File C:\ProgramData\Anaconda3\envs\pycarot\lib\site-packages\scrapy\crawler.py:82, in Crawler.__init__(self, spidercls, settings, init_reactor)
#      80     else:
#      81         from twisted.internet import default
# ---> 82         default.install()
#      83     log_reactor_info()
#      84 if reactor_class:
#
# File C:\ProgramData\Anaconda3\envs\pycarot\lib\site-packages\twisted\internet\selectreactor.py:194, in install()
#     191 reactor = SelectReactor()
#     192 from twisted.internet.main import installReactor
# --> 194 installReactor(reactor)
#
# File C:\ProgramData\Anaconda3\envs\pycarot\lib\site-packages\twisted\internet\main.py:32, in installReactor(reactor)
#      29 import twisted.internet
#      31 if "twisted.internet.reactor" in sys.modules:
# ---> 32     raise error.ReactorAlreadyInstalledError("reactor already installed")
#      33 twisted.internet.reactor = reactor
#      34 sys.modules["twisted.internet.reactor"] = reactor
#
# ReactorAlreadyInstalledError: reactor already installed
